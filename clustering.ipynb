# %%
import pandas as pd

data = pd.read_csv('dataframe/champions.csv')

features = data[['Local', 'GolesLocal', '%_Equipo1_Ganado', '%_1_G_Temporada',
                '%_1_G_Temporada_L', '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G',
                '1_Media_G_Local', '1_Media_Goles_PP', '1_ValorJugadores', '1_MediaJugadores']]


features.sample(10)
# Out:
#       Local  GolesLocal  %_Equipo1_Ganado  %_1_G_Temporada  %_1_G_Temporada_L  \
# 537       5           2             44.44            63.64              80.00
# 352      34           0              0.00            28.57              33.33
# 286     184           2              0.00            20.00               0.00
# 2405     46           1             16.67            55.56              75.00
# 1006      6           1              0.00            20.00              50.00
# 649      28           3             16.67            57.14              66.67
# 696      28           7            100.00            57.14              66.67
# 1613     55           2            100.00            54.55              80.00
# 695      44           1              0.00            20.00               0.00
# 418       7           2              0.00            20.00               0.00
#
#       %_1_E_Temporada_L  %_1_P_Temporada_L  1_Media_G  1_Media_G_Local  \
# 537               20.00               0.00       0.64             0.80
# 352               33.33              33.33       0.29             0.33
# 286               50.00              50.00       0.20             0.00
# 2405              25.00               0.00       0.56             0.75
# 1006               0.00              50.00       0.20             0.50
# 649                0.00              33.33       0.57             0.67
# 696                0.00              33.33       0.57             0.67
# 1613               0.00              20.00       0.55             0.80
# 695                0.00             100.00       0.20             0.00
# 418               50.00              50.00       0.20             0.00
#
#       1_Media_Goles_PP  1_ValorJugadores  1_MediaJugadores
# 537               2.18        821.501532         35.717458
# 352               2.29        491.828396         23.420400
# 286               1.60        408.120531         21.480028
# 2405              1.11        592.778630         29.638932
# 1006              1.40        396.334285         20.859699
# 649               3.43        541.470889         28.498468
# 696               2.86        541.470889         28.498468
# 1613              1.82        750.779751         27.806657
# 695               0.20        383.043922         19.152196
# 418               1.60        370.326864         18.516343

# %% [markdown]
# Hemos seleccionado las características para cada instancia de un equipo. Dado que tenemos 12 características, podríamos interpretarlo como coordenadas que describen una instancia en un espacio de doce diemnsiones. Como el espacio de 12 dimensiones es dificil de visualizar utilizaremos la técnica PCA (Análisis de Componentes Principales) para analizar las relaciones entre características y así reducri la dimensionalidad.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

#Noramlizamos las caracteristicas para que estén en la misma escala
scaled_features = MinMaxScaler().fit_transform(features)

#Conseguir los dos principales componentes
pca = PCA(n_components=2).fit(scaled_features)
features_2d = pca.transform(scaled_features)
features_2d[0:10]  #Mostramos las 10 primeras instancias
# Out:
# array([[-1.06887246, -0.06959706],
#        [-0.26488043, -0.19710935],
#        [-1.00025039, -0.05713479],
#        [ 0.48572254,  0.63420096],
#        [-0.3998359 , -0.37887394],
#        [-0.37756307, -0.38117094],
#        [ 0.55380311,  0.48076071],
#        [ 0.08571122,  0.7082147 ],
#        [-0.65039037,  0.90383364],
#        [-0.01784569,  0.66692134]])

# %%
import matplotlib.pyplot as plt

plt.scatter(features_2d[:,0],features_2d[:,1])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Data')
plt.show()
