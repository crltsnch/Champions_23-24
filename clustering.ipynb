# %%
import pandas as pd

data = pd.read_csv('dataframe/champions_23_24.csv')

# %%
# Seleccionar el último partido jugado por cada equipo local
data = data.groupby('Local').last().reset_index()

# Mostrar el resultado
data
# Out:
#     Local  idPartido   Temporada           Ronda  Visitante  \
# 0       1        114  2023-01-01  Quarter-finals         16
# 1       2         68  2023-01-01     Group stage         14
# 2       3        120  2023-01-01  Quarter-finals         31
# 3       5        117  2023-01-01  Quarter-finals         28
# 4       7        102  2023-01-01     Round of 16         24
# 5       8         83  2023-01-01     Group stage          3
# 6      10         74  2023-01-01     Group stage          7
# 7      12        103  2023-01-01     Round of 16         31
# 8      14        118  2023-01-01  Quarter-finals         24
# 9      15         93  2023-01-01     Group stage         22
# 10     16        119  2023-01-01  Quarter-finals          1
# 11     20         90  2023-01-01     Group stage         16
# 12     21        101  2023-01-01     Round of 16         14
# 13     22         70  2023-01-01     Group stage         24
# 14     24        115  2023-01-01  Quarter-finals         14
# 15     28        116  2023-01-01  Quarter-finals          5
# 16     31        113  2023-01-01  Quarter-finals          3
# 17     50         77  2023-01-01     Group stage          8
# 18     67         71  2023-01-01     Group stage         20
# 19     68         97  2023-01-01     Round of 16          1
# 20     69        106  2023-01-01     Round of 16         28
# 21     80         73  2023-01-01     Group stage         21
# 22     90        104  2023-01-01     Round of 16          5
# 23     92         66  2023-01-01     Group stage        191
# 24     99         99  2023-01-01     Round of 16          3
# 25    153         98  2023-01-01     Round of 16         16
# 26    184         86  2023-01-01     Group stage         10
# 27    191         94  2023-01-01     Group stage          5
# 28    307         91  2023-01-01     Group stage          2
# 29    308         75  2023-01-01     Group stage        470
# 30    328         81  2023-01-01     Group stage         80
# 31    470         87  2023-01-01     Group stage          1
#
#                                Evento  GolesLocal  GolesVisitante  \
# 0           Estadio Santiago Bernabéu           0               0
# 1              Stadio Giuseppe Meazza           1               3
# 2                       Allianz Arena           0               0
# 3       Estadi Olímpic Lluís Companys           0               0
# 4              Stadio Giuseppe Meazza           1               0
# 5                        Old Trafford           0               1
# 6   Estádio do Sport Lisboa e Benfica           3               3
# 7                   Estádio Do Dragão           1               0
# 8                   Signal Iduna Park           0               0
# 9                         Celtic Park           2               1
# 10                     Etihad Stadium           0               0
# 11                Stadion Rajko Mitić           2               3
# 12                    Philips Stadion           1               1
# 13                 Stadion Feijenoord           1               3
# 14      Estadio Cívitas Metropolitano           0               0
# 15                   Parc des Princes           0               0
# 16                   Emirates Stadium           0               0
# 17                          RAMS Park           3               3
# 18                   Stadion Wankdorf           2               0
# 19                     Red Bull Arena           0               1
# 20                        Reale Arena           1               2
# 21      Estadio Ramón Sánchez Pizjuán           2               3
# 22      Stadio Diego Armando Maradona           1               1
# 23            Volksparkstadion (1953)           1               0
# 24                    Stadio Olimpico           1               0
# 25                             Parken           1               3
# 26                     Red Bull Arena           1               3
# 27                      Bosuilstadion           3               2
# 28                     St James' Park           1               2
# 29         Estádio Municipal de Braga           1               1
# 30             Stade Bollaert-Delelis           2               1
# 31              Olympiastadion Berlin           2               3
#
#     VictoriaLocal  Empate  ...  1_MediaJugadores  %_2_G_Temporada  \
# 0               0       1  ...         26.158860            88.89
# 1               0       0  ...         16.423147            33.33
# 2               0       1  ...         24.024071            44.44
# 3               0       1  ...         22.255363            44.44
# 4               1       0  ...         24.558919            44.44
# 5               0       0  ...         15.864402            55.56
# 6               0       1  ...         17.125546            71.43
# 7               1       0  ...         21.329928            44.44
# 8               0       1  ...         21.783541            44.44
# 9               1       0  ...         16.396500            40.00
# 10              0       1  ...         23.287028            77.78
# 11              0       0  ...         17.037329            77.78
# 12              0       1  ...         24.018015            44.44
# 13              0       0  ...         17.166752            33.33
# 14              0       1  ...         25.018572            44.44
# 15              0       1  ...         26.475023            55.56
# 16              0       1  ...         25.125360            66.67
# 17              0       1  ...         20.117467            20.00
# 18              1       0  ...         15.543811             0.00
# 19              0       0  ...         21.643647            66.67
# 20              0       0  ...         20.185433            33.33
# 21              0       0  ...         15.374957            14.29
# 22              0       1  ...         23.106986            55.56
# 23              1       0  ...         17.337906            20.00
# 24              1       0  ...         24.959872            66.67
# 25              0       0  ...         20.163006            77.78
# 26              0       0  ...         16.400942             0.00
# 27              1       0  ...         18.572523            55.56
# 28              0       0  ...         16.767331            20.00
# 29              0       1  ...         17.289159             0.00
# 30              1       0  ...         18.656793             0.00
# 31              0       0  ...         17.483827            66.67
#
#     %_2_G_Temporada_L  %_2_E_Temporada_L  %_2_P_Temporada_L  2_Media_G  \
# 0               80.00              20.00               0.00       0.89
# 1               40.00              60.00               0.00       0.33
# 2               60.00              20.00              20.00       0.44
# 3               60.00              40.00               0.00       0.44
# 4               60.00              20.00              20.00       0.44
# 5               60.00              40.00               0.00       0.56
# 6               75.00              25.00               0.00       0.71
# 7               60.00              20.00              20.00       0.44
# 8               60.00              20.00              20.00       0.44
# 9               66.67               0.00              33.33       0.40
# 10              60.00              40.00               0.00       0.78
# 11              80.00              20.00               0.00       0.78
# 12              40.00              60.00               0.00       0.44
# 13              60.00              20.00              20.00       0.33
# 14              40.00              60.00               0.00       0.44
# 15              80.00              20.00               0.00       0.56
# 16              60.00              40.00               0.00       0.67
# 17              33.33               0.00              66.67       0.20
# 18               0.00              33.33              66.67       0.00
# 19              60.00              40.00               0.00       0.67
# 20              60.00              40.00               0.00       0.33
# 21              25.00              75.00               0.00       0.14
# 22              80.00              20.00               0.00       0.56
# 23              33.33               0.00              66.67       0.20
# 24              60.00              40.00               0.00       0.67
# 25              80.00              20.00               0.00       0.78
# 26               0.00              33.33              66.67       0.00
# 27              80.00              20.00               0.00       0.56
# 28              33.33              33.33              33.33       0.20
# 29               0.00               0.00             100.00       0.00
# 30               0.00              33.33              66.67       0.00
# 31              60.00              40.00               0.00       0.67
#
#     2_Media_G_Local  2_Media_Goles_PP  2_ValorJugadores  2_MediaJugadores
# 0              0.80              2.67        582.175689         23.287028
# 1              0.40              0.78        501.021450         21.783541
# 2              0.60              1.89        552.757916         25.125360
# 3              0.60              1.44        555.975485         26.475023
# 4              0.60              2.11        550.408580         25.018572
# 5              0.60              1.56        552.553626         24.024071
# 6              0.75              1.00        540.296221         24.558919
# 7              0.60              1.89        552.757916         25.125360
# 8              0.60              2.11        550.408580         25.018572
# 9              0.67              1.60        412.002043         17.166752
# 10             0.60              2.00        549.336057         26.158860
# 11             0.80              2.33        582.175689         23.287028
# 12             0.40              1.00        501.021450         21.783541
# 13             0.60              1.78        550.408580         25.018572
# 14             0.40              1.11        501.021450         21.783541
# 15             0.80              1.78        556.384065         22.255363
# 16             0.60              1.67        552.553626         24.024071
# 17             0.33              1.80        380.745659         15.864402
# 18             0.00              1.40        374.821246         17.037329
# 19             0.60              1.89        549.336057         26.158860
# 20             0.60              1.22        555.975485         26.475023
# 21             0.25              0.86        528.396323         24.018015
# 22             0.80              1.67        556.384065         22.255363
# 23             0.33              1.20        371.450460         18.572523
# 24             0.60              1.67        552.553626         24.024071
# 25             0.80              2.33        582.175689         23.287028
# 26             0.00              0.80        376.762002         17.125546
# 27             0.80              1.56        556.384065         22.255363
# 28             0.33              0.60        377.732380         16.423147
# 29             0.00              1.00        367.160368         17.483827
# 30             0.00              1.20        368.998979         15.374957
# 31             0.60              1.67        549.336057         26.158860
#
# [32 rows x 34 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Local                 32 non-null     int64
#  1   idPartido             32 non-null     int64
#  2   Temporada             32 non-null     object
#  3   Ronda                 32 non-null     object
#  4   Visitante             32 non-null     int64
#  5   Evento                32 non-null     object
#  6   GolesLocal            32 non-null     int64
#  7   GolesVisitante        32 non-null     int64
#  8   VictoriaLocal         32 non-null     int64
#  9   Empate                32 non-null     int64
#  10  VictoriaVisitante     32 non-null     int64
#  11  %_Victorias_Local     32 non-null     float64
#  12  %_Empate              32 non-null     float64
#  13  %_Victoria_Visitante  32 non-null     float64
#  14  %_Equipo1_Ganado      32 non-null     float64
#  15  %_Equipo2_Ganado      32 non-null     float64
#  16  %_1_G_Temporada       32 non-null     float64
#  17  %_1_G_Temporada_L     32 non-null     float64
#  18  %_1_E_Temporada_L     32 non-null     float64
#  19  %_1_P_Temporada_L     32 non-null     float64
#  20  1_Media_G             32 non-null     float64
#  21  1_Media_G_Local       32 non-null     float64
#  22  1_Media_Goles_PP      32 non-null     float64
#  23  1_ValorJugadores      32 non-null     float64
#  24  1_MediaJugadores      32 non-null     float64
#  25  %_2_G_Temporada       32 non-null     float64
#  26  %_2_G_Temporada_L     32 non-null     float64
#  27  %_2_E_Temporada_L     32 non-null     float64
#  28  %_2_P_Temporada_L     32 non-null     float64
#  29  2_Media_G             32 non-null     float64
#  30  2_Media_G_Local       32 non-null     float64
#  31  2_Media_Goles_PP      32 non-null     float64
#  32  2_ValorJugadores      32 non-null     float64
#  33  2_MediaJugadores      32 non-null     float64
# dtypes: float64(23), int64(8), object(3)
# memory usage: 8.6+ KB

# %%
features = data[['GolesLocal', '%_Equipo1_Ganado', '%_1_G_Temporada',
                '%_1_G_Temporada_L', '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G',
                '1_Media_G_Local', '1_Media_Goles_PP', '1_ValorJugadores', '1_MediaJugadores']]


features.sample(10)
# Out:
#     GolesLocal  %_Equipo1_Ganado  %_1_G_Temporada  %_1_G_Temporada_L  \
# 8            0             33.33            44.44              50.00
# 27           3              0.00             0.00               0.00
# 23           1            100.00            40.00              50.00
# 17           3             66.67            20.00               0.00
# 21           2              0.00             0.00               0.00
# 11           2              0.00             0.00               0.00
# 4            1            100.00            57.14              66.67
# 9            2              0.00             0.00               0.00
# 29           1            100.00            20.00               0.00
# 2            0             54.55            66.67              75.00
#
#     %_1_E_Temporada_L  %_1_P_Temporada_L  1_Media_G  1_Media_G_Local  \
# 8               50.00                0.0       0.44             0.50
# 27               0.00              100.0       0.00             0.00
# 23               0.00               50.0       0.40             0.50
# 17              50.00               50.0       0.20             0.00
# 21              50.00               50.0       0.00             0.00
# 11              50.00               50.0       0.00             0.00
# 4               33.33                0.0       0.57             0.67
# 9               50.00               50.0       0.00             0.00
# 29               0.00              100.0       0.20             0.00
# 2               25.00                0.0       0.67             0.75
#
#     1_Media_Goles_PP  1_ValorJugadores  1_MediaJugadores
# 8               1.11        501.021450         21.783541
# 27              0.60        371.450460         18.572523
# 23              1.80        364.096016         17.337906
# 17              1.40        402.349336         20.117467
# 21              1.00        368.998979         15.374957
# 11              1.00        374.821246         17.037329
# 4               1.29        540.296221         24.558919
# 9               0.60        377.119510         16.396500
# 29              1.00        397.650664         17.289159
# 2               1.67        552.553626         24.024071

# %% [markdown]
# Hemos seleccionado las características para cada instancia de un equipo. Dado que tenemos 12 características, podríamos interpretarlo como coordenadas que describen una instancia en un espacio de doce diemnsiones. Como el espacio de 12 dimensiones es dificil de visualizar utilizaremos la técnica PCA (Análisis de Componentes Principales) para analizar las relaciones entre características y así reducri la dimensionalidad.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

#Noramlizamos las caracteristicas para que estén en la misma escala
scaled_features = MinMaxScaler().fit_transform(features)

#Conseguir los dos principales componentes
pca = PCA(n_components=2).fit(scaled_features)
features_2d = pca.transform(scaled_features)
features_2d[0:10]  #Mostramos las 10 primeras instancias
# Out:
# array([[ 1.16102665,  0.09161798],
#        [-0.12310998,  0.5454875 ],
#        [ 1.01545443,  0.00905542],
#        [ 1.10035319, -0.2411166 ],
#        [ 0.76388624,  0.02245537],
#        [-0.12024875, -0.49165673],
#        [-1.16088457, -0.25511196],
#        [ 0.70849612, -0.40753698],
#        [ 0.43047069,  0.44758603],
#        [-1.07949897,  0.51407101]])

# %%
import matplotlib.pyplot as plt

plt.scatter(features_2d[:,0],features_2d[:,1])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Data')
plt.show()

# %% [markdown]
# Voy a utilizar una muestra de datos para crear una serie de modelos de agrupamiento con un número creciente de clusters y medir con qué precisión están agrupados los puntos de datos dentro de cada grupo. Para medir la compacidad de los grupos formados por el modelo usaremos la métrica WCSS.
#
# Para determinar el número óptimo de clusters, utilizamos una técnica llamada "método del codo". Este método implica ajustar el modelo de agrupamiento con diferentes números de clusters y calcular el WCSS para cada modelo. Luego, se traza un gráfico del número de clusters en el eje x y el valor de WCSS en el eje y.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

#CRear 10 modelos con 1 hasta 10 clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    # Fit the data points
    kmeans.fit(features.values)
    # Get the WCSS (inertia) value
    wcss.append(kmeans.inertia_)
    
#Plot the WCSS values onto a line graph
plt.plot(range(1, 11), wcss)
plt.title('WCSS by Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Podemos ver un cambio de pendiente notable para 2 y 4 clusters y un cambio de pendiente menos pronunciable para 3 y 5 clusters. El gráfico muestra una gran reducción en el WCSS de 1 a 2 clusters y también una reducción muy notable de dos a tres y de tres a cuatro. A aprtir de 4 clusters la reducción es menos notable. Podemos pensar que hay dos, tres o cuatro clusters de puntos bien separados.
#
# ### K-Means clustering
#
# Utilizo el algoritmo K-Means para crear clusters de prueba. Este es un algoritmo de agrupamiento comúnmente utilizado que separa un conjunto de datos en K clusters de varianza igual. Probaré para K 4 ya que es cuando la curva más se aplana.

# %%
from sklearn.cluster import KMeans

#Función para crear el modelo kmeans
def kmeans(n_clusters, data):
    model = KMeans(n_clusters=n_clusters, init='k-means++', n_init=100, max_iter=1000)
    clusters = model.fit_predict(data)
    return model, clusters

model, km_clusters = kmeans(5, features.values)
km_clusters
# Out:
# array([2, 3, 2, 2, 2, 3, 1, 2, 0, 1, 2, 1, 0, 3, 2, 2, 2, 4, 1, 0, 0, 1,
#        0, 4, 0, 0, 4, 1, 3, 4, 3, 1], dtype=int32)

# %%
#Función para dibujar los graficos con los clusters para los diferentes modelos
import matplotlib.pyplot as plt

local_labels = data['Local']

def plot_clusters_with_labels(samples, clusters, local_labels):
    unique_clusters = set(clusters)
    colors = plt.cm.tab10.colors[:len(unique_clusters)]  # Escoge una paleta de colores
    
    # Diccionario para almacenar los nombres de los clusters y sus colores correspondientes
    cluster_info = {}
    
    for cluster_id, color in zip(unique_clusters, colors):
        cluster_samples = samples[clusters == cluster_id]
        cluster_local_labels = local_labels[clusters == cluster_id]
        for sample, label in zip(cluster_samples, cluster_local_labels):
            plt.scatter(sample[0], sample[1], color=color, marker='o', s=20)
            plt.text(sample[0], sample[1] + 0.01, str(label), fontsize=8, ha='center', va='bottom')
        
        # Añadir una entrada al diccionario con el nombre del cluster y su color
        cluster_info[f'Cluster {cluster_id}'] = color
    
    # Crear leyenda personalizada
    legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=cluster_name,
                                 markerfacecolor=color, markersize=10) 
                      for cluster_name, color in cluster_info.items()]
    
    plt.legend(handles=legend_handles, loc='upper left', bbox_to_anchor=(1.05, 1))
    
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')
    plt.title('Assignments with Local Labels')
    plt.show()

# %%
# Visualizar los clusters con los labels locales
plot_clusters_with_labels(features_2d, km_clusters, local_labels)

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

#Función para evaluar el modelo de clustering
def evaluate_clustering_model(data, labels):
    silhouette = silhouette_score(data, labels)
    calinski_harabasz = calinski_harabasz_score(data, labels)
    davies_bouldin = davies_bouldin_score(data, labels)
    
    print("Silhouette Score:", silhouette)
    print("Calinski-Harabasz Index:", calinski_harabasz)
    print("Davies-Bouldin Score:", davies_bouldin)
    
    return silhouette, calinski_harabasz, davies_bouldin
