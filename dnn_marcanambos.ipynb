# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

class LoadData:
    def __init__(self, file_path):
        self.file_path = file_path

    def load_data(self):
        data = pd.read_csv(self.file_path)
        return data

    def prepare_data(self, data):
        # Convertir la columna "Ronda" en variables dummy
        data = pd.get_dummies(data, columns=['Ronda'], drop_first=True)

        # Suponiendo que tu DataFrame se llama 'dataframe'
        data['MarcanAmbos'] = (data['GolesLocal'] > 0) & (data['GolesVisitante'] > 0)
        data['MarcanAmbos'] = data['MarcanAmbos'].astype(int)

        # Eliminar columnas irrelevantes
        data = data.drop(['idPartido', 'Temporada', 'Evento', 'GolesLocal', 'GolesVisitante'], axis=1)

        # Separar características y etiquetas
        X = data.drop(['VictoriaLocal', 'Empate', 'VictoriaVisitante', 'MarcanAmbos'], axis=1)
        y = data['MarcanAmbos']

        # Escalar características
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        # Dividir los datos en conjuntos de entrenamiento y prueba
        X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
        
        # Convertir los datos a tensores
        X_train = tf.convert_to_tensor(X_train, dtype=tf.float32)
        X_test = tf.convert_to_tensor(X_test, dtype=tf.float32)
        y_train = tf.convert_to_tensor(y_train.values, dtype=tf.float32)
        y_test = tf.convert_to_tensor(y_test.values, dtype=tf.float32)
        
        return X_train, X_test, y_train, y_test, scaler, X, y
    
# Cargar los datos
data_loader = LoadData('dataframe/champions.csv')
data = data_loader.load_data()
X_train, X_test, y_train, y_test, scaler, X, y = data_loader.prepare_data(data)

# %%
X_train.shape
# Out:
# TensorShape([1745, 29])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, Reshape
from tensorflow.keras.optimizers import Adam

class Model:
    def __init__(self, configurations):
        self.configurations = configurations
        self.best_model = None
        self.best_config = None
        self.best_accuracy = 0

    def train_model(self, X_train, y_train):
        for config in self.configurations:
            model = Sequential([
                Reshape((X_train.shape[1], 1), input_shape=(X_train.shape[1],)),
                Conv1D(config['filters'], config['kernel_size'], activation='relu'),
                MaxPooling1D(),
                Flatten(),
                Dense(config['units'], activation='relu'),
                Dropout(config['dropout']),
                Dense(1, activation='sigmoid')
            ])

            optimizer = Adam(learning_rate=config['learning_rate'])
            model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

            history = model.fit(X_train, y_train, epochs=config['epochs'], batch_size=config['batch_size'], validation_split=0.1)
            self.history = history
            
            
            _, accuracy = model.evaluate(X_test, y_test)
            
            if accuracy > self.best_accuracy:
                self.best_accuracy = accuracy
                self.best_model = model
                self.best_config = config

        return self.history
    
    def get_best_model(self):
        return self.best_model
    
    def get_best_config(self):
        return self.best_config
    

# Definir diferentes configuraciones de red y hiperparámetros
configurations = [
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2},
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2}, 
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2},
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2},
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2},
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2},
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2},
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3}
]



model_trainer = Model(configurations)
model_trainer.train_model(X_train, y_train)

model = model_trainer.get_best_model()
best_config = model_trainer.get_best_config()
print("Mejor configuración:", best_config)
# Out:
# Epoch 1/10
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5067 - loss: 0.6995 - val_accuracy: 0.5600 - val_loss: 0.6868
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5300 - loss: 0.6883 - val_accuracy: 0.5257 - val_loss: 0.6904
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5573 - loss: 0.6832 - val_accuracy: 0.5486 - val_loss: 0.6843
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5674 - loss: 0.6765 - val_accuracy: 0.4971 - val_loss: 0.6912
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5721 - loss: 0.6783 - val_accuracy: 0.5486 - val_loss: 0.6798
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5951 - loss: 0.6745 - val_accuracy: 0.5314 - val_loss: 0.6762
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5520 - loss: 0.6802 - val_accuracy: 0.5200 - val_loss: 0.6949
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5715 - loss: 0.6744 - val_accuracy: 0.5543 - val_loss: 0.6843
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5824 - loss: 0.6743 - val_accuracy: 0.5371 - val_loss: 0.6956
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6095 - loss: 0.6646 - val_accuracy: 0.5200 - val_loss: 0.6869
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.5167 - loss: 0.6986
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4917 - loss: 0.8754 - val_accuracy: 0.5943 - val_loss: 0.6837
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5021 - loss: 0.6907 - val_accuracy: 0.4800 - val_loss: 0.6887
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5411 - loss: 0.6906 - val_accuracy: 0.4857 - val_loss: 0.6858
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5396 - loss: 0.6898 - val_accuracy: 0.4800 - val_loss: 0.6903
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5588 - loss: 0.6882 - val_accuracy: 0.5143 - val_loss: 0.6801
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5579 - loss: 0.6875 - val_accuracy: 0.4971 - val_loss: 0.6850
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5580 - loss: 0.6835 - val_accuracy: 0.5257 - val_loss: 0.6839
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5550 - loss: 0.6838 - val_accuracy: 0.5086 - val_loss: 0.6896
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5781 - loss: 0.6768 - val_accuracy: 0.6286 - val_loss: 0.6639
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5573 - loss: 0.6867 - val_accuracy: 0.4914 - val_loss: 0.6980
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5701 - loss: 0.6780 - val_accuracy: 0.4857 - val_loss: 0.7021
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5641 - loss: 0.6808 - val_accuracy: 0.4800 - val_loss: 0.7006
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5701 - loss: 0.6717 - val_accuracy: 0.4914 - val_loss: 0.7080
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5982 - loss: 0.6709 - val_accuracy: 0.5086 - val_loss: 0.6918
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5852 - loss: 0.6788 - val_accuracy: 0.5714 - val_loss: 0.6797
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 0.5054 - loss: 0.7016
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5282 - loss: 0.6952 - val_accuracy: 0.5486 - val_loss: 0.6798
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5331 - loss: 0.6864 - val_accuracy: 0.4857 - val_loss: 0.7002
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5757 - loss: 0.6803 - val_accuracy: 0.4914 - val_loss: 0.6809
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5477 - loss: 0.6846 - val_accuracy: 0.5200 - val_loss: 0.6865
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5585 - loss: 0.6795 - val_accuracy: 0.5600 - val_loss: 0.6930
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5954 - loss: 0.6725 - val_accuracy: 0.5200 - val_loss: 0.6907
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5770 - loss: 0.6756 - val_accuracy: 0.5486 - val_loss: 0.6691
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5754 - loss: 0.6782 - val_accuracy: 0.5314 - val_loss: 0.6816
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5896 - loss: 0.6666 - val_accuracy: 0.5314 - val_loss: 0.6965
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5825 - loss: 0.6667 - val_accuracy: 0.5314 - val_loss: 0.6815
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.5179 - loss: 0.6938
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5190 - loss: 0.6995 - val_accuracy: 0.5029 - val_loss: 0.7002
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5414 - loss: 0.6851 - val_accuracy: 0.5314 - val_loss: 0.6832
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.5495 - loss: 0.6929 - val_accuracy: 0.5371 - val_loss: 0.6787
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.5788 - loss: 0.6780 - val_accuracy: 0.5086 - val_loss: 0.6923
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.5716 - loss: 0.6793 - val_accuracy: 0.5086 - val_loss: 0.6980
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.5737 - loss: 0.6780 - val_accuracy: 0.5143 - val_loss: 0.6948
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5759 - loss: 0.6754 - val_accuracy: 0.5543 - val_loss: 0.6808
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5756 - loss: 0.6790 - val_accuracy: 0.4857 - val_loss: 0.7093
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 0.5750 - loss: 0.6758 - val_accuracy: 0.5086 - val_loss: 0.6826
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5985 - loss: 0.6646 - val_accuracy: 0.5029 - val_loss: 0.6897
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.5474 - loss: 0.6902
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5171 - loss: 0.8244 - val_accuracy: 0.4343 - val_loss: 0.6992
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5003 - loss: 0.6933 - val_accuracy: 0.5200 - val_loss: 0.6916
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5476 - loss: 0.6896 - val_accuracy: 0.5543 - val_loss: 0.6874
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5509 - loss: 0.6874 - val_accuracy: 0.4629 - val_loss: 0.6979
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5625 - loss: 0.6826 - val_accuracy: 0.5086 - val_loss: 0.6961
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5657 - loss: 0.6839 - val_accuracy: 0.4514 - val_loss: 0.7210
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5556 - loss: 0.6792 - val_accuracy: 0.5086 - val_loss: 0.6917
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5829 - loss: 0.6727 - val_accuracy: 0.5829 - val_loss: 0.6747
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5876 - loss: 0.6677 - val_accuracy: 0.4857 - val_loss: 0.6977
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5846 - loss: 0.6757 - val_accuracy: 0.5429 - val_loss: 0.6815
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5745 - loss: 0.6664 - val_accuracy: 0.5314 - val_loss: 0.6870
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5940 - loss: 0.6696 - val_accuracy: 0.5829 - val_loss: 0.6745
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5781 - loss: 0.6678 - val_accuracy: 0.5486 - val_loss: 0.6972
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5964 - loss: 0.6619 - val_accuracy: 0.5429 - val_loss: 0.6885
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6122 - loss: 0.6561 - val_accuracy: 0.5371 - val_loss: 0.7021
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.5205 - loss: 0.7050
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4985 - loss: 0.6981 - val_accuracy: 0.5086 - val_loss: 0.6958
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5544 - loss: 0.6822 - val_accuracy: 0.5143 - val_loss: 0.6943
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5471 - loss: 0.6854 - val_accuracy: 0.5029 - val_loss: 0.6893
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5582 - loss: 0.6816 - val_accuracy: 0.4686 - val_loss: 0.6999
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5780 - loss: 0.6775 - val_accuracy: 0.5314 - val_loss: 0.6884
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5681 - loss: 0.6772 - val_accuracy: 0.5429 - val_loss: 0.6769
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5798 - loss: 0.6727 - val_accuracy: 0.4400 - val_loss: 0.7337
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5774 - loss: 0.6753 - val_accuracy: 0.5486 - val_loss: 0.6779
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5797 - loss: 0.6751 - val_accuracy: 0.5029 - val_loss: 0.6921
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5774 - loss: 0.6756 - val_accuracy: 0.4743 - val_loss: 0.7128
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.5263 - loss: 0.6955
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5053 - loss: 0.7089 - val_accuracy: 0.4686 - val_loss: 0.7013
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5512 - loss: 0.6853 - val_accuracy: 0.5314 - val_loss: 0.6871
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.5438 - loss: 0.6873 - val_accuracy: 0.5429 - val_loss: 0.6825
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.5674 - loss: 0.6807 - val_accuracy: 0.5429 - val_loss: 0.6790
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.5785 - loss: 0.6693 - val_accuracy: 0.4743 - val_loss: 0.7122
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - accuracy: 0.5535 - loss: 0.6842 - val_accuracy: 0.5029 - val_loss: 0.6909
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.5673 - loss: 0.6744 - val_accuracy: 0.5771 - val_loss: 0.6775
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5874 - loss: 0.6724 - val_accuracy: 0.4857 - val_loss: 0.7174
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5769 - loss: 0.6772 - val_accuracy: 0.4857 - val_loss: 0.7164
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5961 - loss: 0.6664 - val_accuracy: 0.5143 - val_loss: 0.6888
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - accuracy: 0.5399 - loss: 0.6931
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4898 - loss: 0.8034 - val_accuracy: 0.5314 - val_loss: 0.6868
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5390 - loss: 0.6895 - val_accuracy: 0.4857 - val_loss: 0.6890
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5418 - loss: 0.6872 - val_accuracy: 0.5486 - val_loss: 0.6822
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5291 - loss: 0.6871 - val_accuracy: 0.5257 - val_loss: 0.6811
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5556 - loss: 0.6839 - val_accuracy: 0.6057 - val_loss: 0.6680
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5563 - loss: 0.6862 - val_accuracy: 0.5771 - val_loss: 0.6717
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5898 - loss: 0.6759 - val_accuracy: 0.5257 - val_loss: 0.6965
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5892 - loss: 0.6756 - val_accuracy: 0.5200 - val_loss: 0.6942
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5850 - loss: 0.6727 - val_accuracy: 0.5200 - val_loss: 0.6863
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5964 - loss: 0.6681 - val_accuracy: 0.5200 - val_loss: 0.7028
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5616 - loss: 0.6746 - val_accuracy: 0.4914 - val_loss: 0.7296
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5801 - loss: 0.6624 - val_accuracy: 0.5086 - val_loss: 0.6953
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5743 - loss: 0.6638 - val_accuracy: 0.5029 - val_loss: 0.7134
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5781 - loss: 0.6591 - val_accuracy: 0.5829 - val_loss: 0.6852
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6065 - loss: 0.6554 - val_accuracy: 0.5543 - val_loss: 0.6869
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - accuracy: 0.4810 - loss: 0.7135
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4908 - loss: 0.6999 - val_accuracy: 0.5200 - val_loss: 0.6922
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5457 - loss: 0.6870 - val_accuracy: 0.4743 - val_loss: 0.7091
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5523 - loss: 0.6860 - val_accuracy: 0.5200 - val_loss: 0.6908
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5661 - loss: 0.6793 - val_accuracy: 0.4686 - val_loss: 0.7026
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5444 - loss: 0.6840 - val_accuracy: 0.4971 - val_loss: 0.6954
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5907 - loss: 0.6756 - val_accuracy: 0.5257 - val_loss: 0.6745
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6004 - loss: 0.6690 - val_accuracy: 0.5429 - val_loss: 0.6766
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5726 - loss: 0.6765 - val_accuracy: 0.5314 - val_loss: 0.6774
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5461 - loss: 0.6819 - val_accuracy: 0.5543 - val_loss: 0.6770
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5901 - loss: 0.6639 - val_accuracy: 0.5257 - val_loss: 0.6838
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.5160 - loss: 0.6933
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4779 - loss: 0.6978 - val_accuracy: 0.4914 - val_loss: 0.6927
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5476 - loss: 0.6869 - val_accuracy: 0.5714 - val_loss: 0.6769
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5562 - loss: 0.6838 - val_accuracy: 0.4857 - val_loss: 0.6923
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5602 - loss: 0.6855 - val_accuracy: 0.5429 - val_loss: 0.6789
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5873 - loss: 0.6771 - val_accuracy: 0.5314 - val_loss: 0.6817
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5764 - loss: 0.6725 - val_accuracy: 0.5200 - val_loss: 0.6847
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5799 - loss: 0.6698 - val_accuracy: 0.5429 - val_loss: 0.6745
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5791 - loss: 0.6778 - val_accuracy: 0.5029 - val_loss: 0.6974
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5926 - loss: 0.6699 - val_accuracy: 0.5257 - val_loss: 0.6850
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5968 - loss: 0.6684 - val_accuracy: 0.4971 - val_loss: 0.7030
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.5541 - loss: 0.6906
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5083 - loss: 0.6998 - val_accuracy: 0.5314 - val_loss: 0.6910
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.5517 - loss: 0.6820 - val_accuracy: 0.5657 - val_loss: 0.6804
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.5808 - loss: 0.6821 - val_accuracy: 0.5371 - val_loss: 0.6949
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.5658 - loss: 0.6856 - val_accuracy: 0.5371 - val_loss: 0.6958
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.5700 - loss: 0.6818 - val_accuracy: 0.5371 - val_loss: 0.6853
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.5730 - loss: 0.6784 - val_accuracy: 0.5657 - val_loss: 0.6838
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.5860 - loss: 0.6752 - val_accuracy: 0.5600 - val_loss: 0.6787
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.5781 - loss: 0.6745 - val_accuracy: 0.5029 - val_loss: 0.6934
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.5615 - loss: 0.6753 - val_accuracy: 0.5486 - val_loss: 0.6881
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.5980 - loss: 0.6679 - val_accuracy: 0.4971 - val_loss: 0.6997
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - accuracy: 0.5274 - loss: 0.6926
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5218 - loss: 0.8749 - val_accuracy: 0.5829 - val_loss: 0.6897
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5220 - loss: 0.6914 - val_accuracy: 0.4743 - val_loss: 0.6926
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5395 - loss: 0.6915 - val_accuracy: 0.4914 - val_loss: 0.6979
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5333 - loss: 0.6882 - val_accuracy: 0.4800 - val_loss: 0.6936
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5513 - loss: 0.6829 - val_accuracy: 0.4971 - val_loss: 0.6871
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5708 - loss: 0.6829 - val_accuracy: 0.4857 - val_loss: 0.6959
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5781 - loss: 0.6838 - val_accuracy: 0.4800 - val_loss: 0.7013
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5911 - loss: 0.6731 - val_accuracy: 0.5600 - val_loss: 0.6949
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5792 - loss: 0.6854 - val_accuracy: 0.5029 - val_loss: 0.6764
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5614 - loss: 0.6849 - val_accuracy: 0.5200 - val_loss: 0.6880
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5883 - loss: 0.6702 - val_accuracy: 0.5143 - val_loss: 0.7011
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5895 - loss: 0.6662 - val_accuracy: 0.5829 - val_loss: 0.6639
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5847 - loss: 0.6714 - val_accuracy: 0.5943 - val_loss: 0.6814
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6060 - loss: 0.6633 - val_accuracy: 0.5257 - val_loss: 0.6990
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5961 - loss: 0.6665 - val_accuracy: 0.5429 - val_loss: 0.6885
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.5251 - loss: 0.7077
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4954 - loss: 0.6959 - val_accuracy: 0.4686 - val_loss: 0.6969
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5469 - loss: 0.6879 - val_accuracy: 0.5486 - val_loss: 0.6777
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5234 - loss: 0.6913 - val_accuracy: 0.5143 - val_loss: 0.6810
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5515 - loss: 0.6850 - val_accuracy: 0.5029 - val_loss: 0.6908
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5719 - loss: 0.6777 - val_accuracy: 0.5257 - val_loss: 0.6910
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5662 - loss: 0.6784 - val_accuracy: 0.5200 - val_loss: 0.6791
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5715 - loss: 0.6734 - val_accuracy: 0.5200 - val_loss: 0.6790
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6025 - loss: 0.6642 - val_accuracy: 0.5714 - val_loss: 0.6699
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5973 - loss: 0.6661 - val_accuracy: 0.5257 - val_loss: 0.7048
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5862 - loss: 0.6719 - val_accuracy: 0.5257 - val_loss: 0.6775
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.5194 - loss: 0.6955
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5024 - loss: 0.7057 - val_accuracy: 0.4857 - val_loss: 0.7047
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.5295 - loss: 0.6915 - val_accuracy: 0.4914 - val_loss: 0.7106
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.5498 - loss: 0.6818 - val_accuracy: 0.4571 - val_loss: 0.7226
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.5279 - loss: 0.6911 - val_accuracy: 0.4743 - val_loss: 0.7054
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.5731 - loss: 0.6752 - val_accuracy: 0.5143 - val_loss: 0.6785
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.5646 - loss: 0.6797 - val_accuracy: 0.4686 - val_loss: 0.7077
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.5724 - loss: 0.6747 - val_accuracy: 0.4914 - val_loss: 0.7104
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.5767 - loss: 0.6759 - val_accuracy: 0.4914 - val_loss: 0.6951
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.5664 - loss: 0.6784 - val_accuracy: 0.5029 - val_loss: 0.7096
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.5806 - loss: 0.6724 - val_accuracy: 0.5029 - val_loss: 0.7066
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - accuracy: 0.5398 - loss: 0.6919
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4964 - loss: 0.7621 - val_accuracy: 0.5600 - val_loss: 0.6877
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5292 - loss: 0.6927 - val_accuracy: 0.4971 - val_loss: 0.6915
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5478 - loss: 0.6884 - val_accuracy: 0.5143 - val_loss: 0.6911
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5316 - loss: 0.6868 - val_accuracy: 0.4743 - val_loss: 0.6912
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5562 - loss: 0.6876 - val_accuracy: 0.5429 - val_loss: 0.6799
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5634 - loss: 0.6821 - val_accuracy: 0.5200 - val_loss: 0.6768
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5592 - loss: 0.6780 - val_accuracy: 0.5257 - val_loss: 0.6886
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5611 - loss: 0.6805 - val_accuracy: 0.5257 - val_loss: 0.6892
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5598 - loss: 0.6804 - val_accuracy: 0.5143 - val_loss: 0.6915
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5862 - loss: 0.6725 - val_accuracy: 0.4971 - val_loss: 0.7008
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6103 - loss: 0.6677 - val_accuracy: 0.4971 - val_loss: 0.7199
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5859 - loss: 0.6686 - val_accuracy: 0.4743 - val_loss: 0.7102
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5754 - loss: 0.6704 - val_accuracy: 0.5429 - val_loss: 0.6871
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5899 - loss: 0.6717 - val_accuracy: 0.5257 - val_loss: 0.7206
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5971 - loss: 0.6695 - val_accuracy: 0.5029 - val_loss: 0.7166
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - accuracy: 0.4783 - loss: 0.7157
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5118 - loss: 0.6997 - val_accuracy: 0.5429 - val_loss: 0.6960
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5469 - loss: 0.6867 - val_accuracy: 0.5486 - val_loss: 0.6799
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5524 - loss: 0.6836 - val_accuracy: 0.5143 - val_loss: 0.6840
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5520 - loss: 0.6773 - val_accuracy: 0.5429 - val_loss: 0.6784
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5834 - loss: 0.6761 - val_accuracy: 0.5429 - val_loss: 0.6811
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5735 - loss: 0.6761 - val_accuracy: 0.5371 - val_loss: 0.6762
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5689 - loss: 0.6742 - val_accuracy: 0.5543 - val_loss: 0.6694
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5884 - loss: 0.6710 - val_accuracy: 0.5143 - val_loss: 0.6967
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5904 - loss: 0.6686 - val_accuracy: 0.5600 - val_loss: 0.6825
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5770 - loss: 0.6702 - val_accuracy: 0.5143 - val_loss: 0.6766
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.5330 - loss: 0.6877
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5107 - loss: 0.6980 - val_accuracy: 0.4686 - val_loss: 0.7013
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5004 - loss: 0.6974 - val_accuracy: 0.5200 - val_loss: 0.6860
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5610 - loss: 0.6861 - val_accuracy: 0.5543 - val_loss: 0.6810
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.5516 - loss: 0.6815 - val_accuracy: 0.5143 - val_loss: 0.6773
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - accuracy: 0.5487 - loss: 0.6983 - val_accuracy: 0.5429 - val_loss: 0.6761
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.5598 - loss: 0.6806 - val_accuracy: 0.5314 - val_loss: 0.6920
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - accuracy: 0.5737 - loss: 0.6783 - val_accuracy: 0.5314 - val_loss: 0.6956
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.5995 - loss: 0.6671 - val_accuracy: 0.5314 - val_loss: 0.6758
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - accuracy: 0.5840 - loss: 0.6711 - val_accuracy: 0.5200 - val_loss: 0.6856
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.5864 - loss: 0.6680 - val_accuracy: 0.5257 - val_loss: 0.6805
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - accuracy: 0.5064 - loss: 0.6927
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4834 - loss: 0.8096 - val_accuracy: 0.5486 - val_loss: 0.6903
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5115 - loss: 0.6918 - val_accuracy: 0.5143 - val_loss: 0.6934
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5252 - loss: 0.6922 - val_accuracy: 0.4857 - val_loss: 0.6953
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5598 - loss: 0.6833 - val_accuracy: 0.5029 - val_loss: 0.6939
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5729 - loss: 0.6802 - val_accuracy: 0.5371 - val_loss: 0.6912
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5741 - loss: 0.6750 - val_accuracy: 0.5143 - val_loss: 0.6986
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5982 - loss: 0.6682 - val_accuracy: 0.5429 - val_loss: 0.6894
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5720 - loss: 0.6721 - val_accuracy: 0.5143 - val_loss: 0.6836
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6040 - loss: 0.6610 - val_accuracy: 0.5600 - val_loss: 0.6939
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5817 - loss: 0.6798 - val_accuracy: 0.4971 - val_loss: 0.7186
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6175 - loss: 0.6631 - val_accuracy: 0.4857 - val_loss: 0.6877
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6176 - loss: 0.6544 - val_accuracy: 0.5657 - val_loss: 0.6891
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6064 - loss: 0.6538 - val_accuracy: 0.5429 - val_loss: 0.7316
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5890 - loss: 0.6641 - val_accuracy: 0.4914 - val_loss: 0.7574
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5804 - loss: 0.6780 - val_accuracy: 0.5257 - val_loss: 0.6967
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.5108 - loss: 0.7012
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4905 - loss: 0.6974 - val_accuracy: 0.4686 - val_loss: 0.6972
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5666 - loss: 0.6845 - val_accuracy: 0.4743 - val_loss: 0.6887
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5559 - loss: 0.6844 - val_accuracy: 0.5829 - val_loss: 0.6749
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5712 - loss: 0.6836 - val_accuracy: 0.5429 - val_loss: 0.6776
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5836 - loss: 0.6766 - val_accuracy: 0.5486 - val_loss: 0.6896
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5551 - loss: 0.6781 - val_accuracy: 0.5200 - val_loss: 0.6828
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6005 - loss: 0.6710 - val_accuracy: 0.5371 - val_loss: 0.6798
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5821 - loss: 0.6714 - val_accuracy: 0.4971 - val_loss: 0.6992
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5855 - loss: 0.6707 - val_accuracy: 0.5200 - val_loss: 0.6971
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5832 - loss: 0.6721 - val_accuracy: 0.5314 - val_loss: 0.6977
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - accuracy: 0.5478 - loss: 0.6894
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4785 - loss: 0.7145 - val_accuracy: 0.5029 - val_loss: 0.6906
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.5437 - loss: 0.6885 - val_accuracy: 0.4971 - val_loss: 0.6927
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.5468 - loss: 0.6903 - val_accuracy: 0.5086 - val_loss: 0.6928
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.5543 - loss: 0.6845 - val_accuracy: 0.4857 - val_loss: 0.7067
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.5521 - loss: 0.6787 - val_accuracy: 0.5429 - val_loss: 0.6930
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.5748 - loss: 0.6749 - val_accuracy: 0.5257 - val_loss: 0.6941
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.5877 - loss: 0.6728 - val_accuracy: 0.5543 - val_loss: 0.6884
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.6014 - loss: 0.6683 - val_accuracy: 0.5200 - val_loss: 0.6803
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.5647 - loss: 0.6789 - val_accuracy: 0.4971 - val_loss: 0.7263
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.5881 - loss: 0.6687 - val_accuracy: 0.5143 - val_loss: 0.6971
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - accuracy: 0.5370 - loss: 0.6934
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4980 - loss: 0.8301 - val_accuracy: 0.5943 - val_loss: 0.6855
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4989 - loss: 0.6922 - val_accuracy: 0.4800 - val_loss: 0.6903
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5471 - loss: 0.6908 - val_accuracy: 0.4857 - val_loss: 0.6882
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5475 - loss: 0.6875 - val_accuracy: 0.5086 - val_loss: 0.6897
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5402 - loss: 0.6851 - val_accuracy: 0.4914 - val_loss: 0.6805
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5486 - loss: 0.6867 - val_accuracy: 0.5143 - val_loss: 0.6818
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5530 - loss: 0.6812 - val_accuracy: 0.6229 - val_loss: 0.6653
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5547 - loss: 0.6854 - val_accuracy: 0.5429 - val_loss: 0.6786
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5748 - loss: 0.6733 - val_accuracy: 0.4914 - val_loss: 0.7025
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5702 - loss: 0.6726 - val_accuracy: 0.5086 - val_loss: 0.7000
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5656 - loss: 0.6785 - val_accuracy: 0.5086 - val_loss: 0.7188
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5673 - loss: 0.6756 - val_accuracy: 0.4971 - val_loss: 0.7050
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5805 - loss: 0.6721 - val_accuracy: 0.4914 - val_loss: 0.6925
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5755 - loss: 0.6662 - val_accuracy: 0.4857 - val_loss: 0.7042
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5884 - loss: 0.6691 - val_accuracy: 0.5029 - val_loss: 0.7302
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.5233 - loss: 0.7192
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5121 - loss: 0.6964 - val_accuracy: 0.4171 - val_loss: 0.7160
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5490 - loss: 0.6851 - val_accuracy: 0.4971 - val_loss: 0.6920
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5536 - loss: 0.6896 - val_accuracy: 0.5371 - val_loss: 0.6823
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5544 - loss: 0.6823 - val_accuracy: 0.5486 - val_loss: 0.6742
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5560 - loss: 0.6795 - val_accuracy: 0.5143 - val_loss: 0.6878
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6046 - loss: 0.6717 - val_accuracy: 0.5257 - val_loss: 0.6826
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5741 - loss: 0.6788 - val_accuracy: 0.5143 - val_loss: 0.7041
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5787 - loss: 0.6704 - val_accuracy: 0.5486 - val_loss: 0.6788
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5818 - loss: 0.6702 - val_accuracy: 0.5371 - val_loss: 0.6767
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6039 - loss: 0.6674 - val_accuracy: 0.5314 - val_loss: 0.6818
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.5149 - loss: 0.6945
# Mejor configuración: {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2}

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix

class ModelEvaluation:
    def __init__(self, model):
        self.model = model
    
    def evaluate_model(self, X_test, y_test):
        # Evaluar el modelo
        loss, accuracy = self.model.evaluate(X_test, y_test)
        print("Loss:", loss)
        print("Accuracy:", accuracy)

        # Generar predicciones
        class_probabilities = self.model.predict(X_test)
        predictions = np.round(class_probabilities).flatten()
        true_labels = y_test.numpy().flatten()

        # Calcular y mostrar la matriz de confusión
        conf_matrix = confusion_matrix(true_labels, predictions)
        print("Confusion Matrix:")
        print(conf_matrix)

        self.plot_matriz_confusion(conf_matrix)

    def plot_matriz_confusion(self, conf_matrix):
        # Visualizar la matriz de confusión
        plt.imshow(conf_matrix, interpolation="nearest", cmap=plt.cm.Blues)
        plt.colorbar()
        tick_marks = np.arange(2)
        plt.xticks(tick_marks, ['No Marcan Ambos', 'Marcan Ambos'], rotation=45)
        plt.yticks(tick_marks, ['No Marcan Ambos', 'Marcan Ambos'])
        plt.xlabel("Predicted Class")
        plt.ylabel("True Class")
        plt.title("Confusion Matrix")
        plt.show()

    @staticmethod
    def plot_learning_curve_tf(history):
        train_loss = history['loss']
        val_loss = history['val_loss']
        train_accuracy = history['accuracy']
        val_accuracy = history['val_accuracy']
        
        epochs = range(1, len(train_loss) + 1)
        
        plt.figure(figsize=(20, 6))
        
        plt.subplot(1, 2, 1)
        plt.plot(epochs, train_loss, 'r', label='Training loss')
        plt.plot(epochs, val_loss, 'b', label='Validation loss')
        plt.title('Training and validation loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        
        plt.subplot(1, 2, 2)
        plt.plot(epochs, train_accuracy, 'r', label='Training accuracy')
        plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        
        plt.show()

# Asumiendo que ya tienes el modelo entrenado (model) y los datos de prueba (X_test, y_test)
model_evaluator = ModelEvaluation(model)
model_evaluator.evaluate_model(X_test, y_test)

ModelEvaluation.plot_learning_curve_tf(model_trainer.history)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - accuracy: 0.5474 - loss: 0.6902
# Loss: 0.6907649040222168
# Accuracy: 0.5420560836791992
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Confusion Matrix:
# [[215 172]
#  [171 191]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 73
#      70 model_evaluator = ModelEvaluation(model)
#      71 model_evaluator.evaluate_model(X_test, y_test)
# ---> 73 ModelEvaluation.plot_learning_curve_tf(model_trainer.history)
#
# Cell In[12], line 42, in ModelEvaluation.plot_learning_curve_tf(history)
#      40 @staticmethod
#      41 def plot_learning_curve_tf(history):
# ---> 42     train_loss = history['loss']
#      43     val_loss = history['val_loss']
#      44     train_accuracy = history['accuracy']
#
# TypeError: 'History' object is not subscriptable

# %%
# Guardar el modelo
tf.keras.models.save_model(model, 'modelos/dnn_ambos_marcan.keras')
model = tf.keras.models.load_model("modelos/dnn_ambos_marcan.keras")

# %%
import pandas as pd

# Cargar los datos
df = pd.read_csv("dataframe/champions_23_24.csv")
df = pd.concat([df, data], ignore_index=True)

# Suponiendo que tu DataFrame se llama df
df = df.sort_values(by=['Temporada', 'Ronda'], ascending=[True, True])
df = pd.get_dummies(df, columns=['Ronda'], drop_first=True)

df
# Out:
#       idPartido   Temporada  Local  Visitante  \
# 2617       2618  2003-01-01     27         12
# 2493       2494  2003-01-01     38        190
# 2494       2495  2003-01-01     76         11
# 2495       2496  2003-01-01     36         12
# 2496       2497  2003-01-01     49        151
# ...         ...         ...    ...        ...
# 111         112  2023-01-01     24          7
# 120         121  2023-01-01      3          1
# 121         122  2023-01-01     14         28
# 122         123  2023-01-01     28         14
# 123         124  2023-01-01      1          3
#
#                                Evento  GolesLocal  GolesVisitante  \
# 2617  Arena AufSchalke (Neutral Site)           0               3
# 2493               Jan Breydelstadion           1               1
# 2494                    Stadion Letná           0               1
# 2495              Stadion FK Partizan           1               1
# 2496                    Ibrox Stadium           2               1
# ...                               ...         ...             ...
# 111             Stadium Metropolitano           2               1
# 120                     Allianz Arena           0               0
# 121                 Signal Iduna Park           0               0
# 122                  Parc des Princes           0               0
# 123         Estadio Santiago Bernabéu           0               0
#
#       VictoriaLocal  Empate  VictoriaVisitante  ...  %_2_P_Temporada_L  \
# 2617              0       0                  1  ...              16.67
# 2493              0       1                  0  ...              25.00
# 2494              0       0                  1  ...              16.67
# 2495              0       1                  0  ...              16.67
# 2496              1       0                  0  ...              25.00
# ...             ...     ...                ...  ...                ...
# 111               0       0                  1  ...               0.00
# 120               0       1                  0  ...               0.00
# 121               0       1                  0  ...              16.67
# 122               0       1                  0  ...               0.00
# 123               0       1                  0  ...               0.00
#
#       2_Media_G  2_Media_G_Local  2_Media_Goles_PP  2_ValorJugadores  \
# 2617       0.50             0.67              1.42        765.322916
# 2493       0.29             0.25              1.14        491.567176
# 2494       0.45             0.17              1.36        694.733672
# 2495       0.58             0.67              1.58        765.322916
# 2496       0.57             0.75              1.14        512.353693
# ...         ...              ...               ...               ...
# 111        0.57             0.75              1.29        540.296221
# 120        0.73             0.50              2.00        685.750766
# 121        0.45             0.50              1.73        698.621042
# 122        0.45             0.50              1.36        642.492339
# 123        0.64             0.67              1.64        675.229826
#
#       2_MediaJugadores  Ronda_Group stage  Ronda_Quarter-finals  \
# 2617         34.787405              False                 False
# 2493         23.407961               True                 False
# 2494         33.082556               True                 False
# 2495         34.787405               True                 False
# 2496         24.397795               True                 False
# ...                ...                ...                   ...
# 111          24.558919              False                 False
# 120          31.170489              False                 False
# 121          33.267669              False                 False
# 122          27.934450              False                 False
# 123          29.357819              False                 False
#
#       Ronda_Round of 16  Ronda_Semi-finals
# 2617              False              False
# 2493              False              False
# 2494              False              False
# 2495              False              False
# 2496              False              False
# ...                 ...                ...
# 111                True              False
# 120               False               True
# 121               False               True
# 122               False               True
# 123               False               True
#
# [2618 rows x 37 columns]

# %%
def datos_usuario(df, equipo_local, equipo_visitante):
    # Filtrar el DataFrame para obtener la última fila donde el equipo local y visitante coincidan con los ingresados por el usuario
    filtro_ultimo_partido = ((df['Local'] == equipo_local) & (df['Visitante'] == equipo_visitante)) | ((df['Local'] == equipo_visitante) & (df['Visitante'] == equipo_local))

    # Obtener el último partido entre los equipos ingresados por el usuario
    ultimo_partido_entre_equipos = df[filtro_ultimo_partido].iloc[-1]

    # Obtener los valores para las columnas %_Victorias_Local, %_Empate, %_Victoria_Visitante
    valores_prediccion = ultimo_partido_entre_equipos[['%_Victorias_Local', '%_Empate', '%_Victoria_Visitante', 'Ronda_Group stage', 'Ronda_Quarter-finals',	'Ronda_Round of 16', 'Ronda_Semi-finals']]

    if ultimo_partido_entre_equipos['Local'] == equipo_local and ultimo_partido_entre_equipos['Visitante'] == equipo_visitante:
        porcentajes_de_los_dos = ultimo_partido_entre_equipos[['%_Equipo1_Ganado', '%_Equipo2_Ganado']]

    elif ultimo_partido_entre_equipos['Local'] == equipo_visitante and ultimo_partido_entre_equipos['Visitante'] == equipo_local:
        porcentajes_de_los_dos = ultimo_partido_entre_equipos[['%_Equipo1_Ganado', '%_Equipo2_Ganado']]
        porcentajes_de_los_dos = porcentajes_de_los_dos.rename({'%_Equipo1_Ganado': '%_Equipo2_Ganado', '%_Equipo2_Ganado': '%_Equipo1_Ganado'})


    # 3. Filtrar el DataFrame para obtener las estadísticas del equipo local
    filtro_local = (df['Local'] == equipo_local) | (df['Visitante'] == equipo_local)
    ultima_aparicion_local = df[filtro_local].iloc[-1]
    if ultima_aparicion_local['Local'] == equipo_local:
        estadisticas_equipo_local = ultima_aparicion_local[['%_1_G_Temporada', '%_1_G_Temporada_L', '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G', '1_Media_G_Local', '1_Media_Goles_PP', '1_ValorJugadores', '1_MediaJugadores']]
    elif ultima_aparicion_local['Visitante'] == equipo_local:
        estadisticas_equipo_local = ultima_aparicion_local[['%_2_G_Temporada', '%_2_G_Temporada_L', '%_2_E_Temporada_L', '%_2_P_Temporada_L', '2_Media_G', '2_Media_G_Local', '2_Media_Goles_PP', '2_ValorJugadores', '2_MediaJugadores']]
        #Cambiar el numero del nombre de las columnas porque si es el local del usuario pasara a ser las columnas con 1 en vez de 2
        estadisticas_equipo_local.index = ['%_1_G_Temporada', '%_1_G_Temporada_L', '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G', '1_Media_G_Local', '1_Media_Goles_PP', '1_ValorJugadores', '1_MediaJugadores']

    # 4. Filtrar el DataFrame para obtener las estadísticas del equipo visitante
    filtro_visitante = (df['Local'] == equipo_visitante) | (df['Visitante'] == equipo_visitante)
    ultima_aparicion_visitante = df[filtro_visitante].iloc[-1]
    if ultima_aparicion_visitante['Local'] == equipo_visitante:
        estadisticas_equipo_visitante = ultima_aparicion_visitante[['%_1_G_Temporada', '%_1_G_Temporada_L', '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G', '1_Media_G_Local', '1_Media_Goles_PP', '1_ValorJugadores', '1_MediaJugadores']]
        estadisticas_equipo_visitante = estadisticas_equipo_visitante.rename({'%_1_G_Temporada': '%_2_G_Temporada', '%_1_G_Temporada_L': '%_2_G_Temporada_L', '%_1_E_Temporada_L': '%_2_E_Temporada_L', '%_1_P_Temporada_L': '%_2_P_Temporada_L', '1_Media_G': '2_Media_G', '1_Media_G_Local': '2_Media_G_Local', '1_Media_Goles_PP': '2_Media_Goles_PP', '1_ValorJugadores': '2_ValorJugadores', '1_MediaJugadores': '2_MediaJugadores'})
    elif ultima_aparicion_visitante['Visitante'] == equipo_visitante:
        estadisticas_equipo_visitante = ultima_aparicion_visitante[['%_2_G_Temporada', '%_2_G_Temporada_L', '%_2_E_Temporada_L', '%_2_P_Temporada_L', '2_Media_G', '2_Media_G_Local', '2_Media_Goles_PP', '2_ValorJugadores', '2_MediaJugadores']]


    # Combinar las estadísticas de ambos equipos para predecir el resultado del partido
    datos_partido = pd.concat([estadisticas_equipo_local, estadisticas_equipo_visitante, valores_prediccion, porcentajes_de_los_dos])

    # Crear un nuevo DataFrame vacío con las columnas especificadas en el orden deseado
    nuevo_dataframe = pd.DataFrame(columns=['Local', 'Visitante', '%_Victorias_Local', '%_Empate', '%_Victoria_Visitante',
                                            '%_Equipo1_Ganado', '%_Equipo2_Ganado', '%_1_G_Temporada', '%_1_G_Temporada_L',
                                            '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G', '1_Media_G_Local', '1_Media_Goles_PP',
                                            '1_ValorJugadores', '1_MediaJugadores', '%_2_G_Temporada', '%_2_G_Temporada_L',
                                            '%_2_E_Temporada_L', '%_2_P_Temporada_L', '2_Media_G', '2_Media_G_Local', '2_Media_Goles_PP',
                                            '2_ValorJugadores', '2_MediaJugadores', 'Ronda_Group stage', 'Ronda_Quarter-finals', 'Ronda_Round of 16', 'Ronda_Semi-finals'])

    # Agregar una fila con los valores proporcionados al nuevo DataFrame
    nuevo_dataframe.loc[0] = [equipo_local, equipo_visitante, datos_partido['%_Victorias_Local'], datos_partido['%_Empate'],
                            datos_partido['%_Victoria_Visitante'], datos_partido['%_Equipo1_Ganado'], datos_partido['%_Equipo2_Ganado'],
                            datos_partido['%_1_G_Temporada'], datos_partido['%_1_G_Temporada_L'], datos_partido['%_1_E_Temporada_L'],
                            datos_partido['%_1_P_Temporada_L'], datos_partido['1_Media_G'], datos_partido['1_Media_G_Local'],
                            datos_partido['1_Media_Goles_PP'], datos_partido['1_ValorJugadores'], datos_partido['1_MediaJugadores'],
                            datos_partido['%_2_G_Temporada'], datos_partido['%_2_G_Temporada_L'], datos_partido['%_2_E_Temporada_L'],
                            datos_partido['%_2_P_Temporada_L'], datos_partido['2_Media_G'], datos_partido['2_Media_G_Local'],
                            datos_partido['2_Media_Goles_PP'], datos_partido['2_ValorJugadores'], datos_partido['2_MediaJugadores'],
                            datos_partido['Ronda_Group stage'], datos_partido['Ronda_Quarter-finals'], datos_partido['Ronda_Round of 16'], datos_partido['Ronda_Semi-finals']]


    return nuevo_dataframe


datos_usuario(df, 14, 28)
# Out:
#    Local  Visitante  %_Victorias_Local  %_Empate  %_Victoria_Visitante  \
# 0     14         28               60.0      40.0                   0.0
#
#    %_Equipo1_Ganado  %_Equipo2_Ganado  %_1_G_Temporada  %_1_G_Temporada_L  \
# 0              20.0              40.0            45.45               50.0
#
#    %_1_E_Temporada_L  ...  %_2_P_Temporada_L  2_Media_G  2_Media_G_Local  \
# 0               50.0  ...               20.0       0.45              0.6
#
#    2_Media_Goles_PP  2_ValorJugadores  2_MediaJugadores  Ronda_Group stage  \
# 0              1.73        698.621042         33.267669              False
#
#    Ronda_Quarter-finals  Ronda_Round of 16  Ronda_Semi-finals
# 0                 False              False               True
#
# [1 rows x 29 columns]

# %%
def main():
    # 1. Pedir al usuario que ingrese el equipo local
    print("Seleccione el equipo local:")
    equipos_disponibles = df['Local'].unique()
    print(equipos_disponibles)

    equipo_local = int(input("Ingrese el nombre del equipo local: "))
    equipo_visitante = int(input("Ingrese el nombre del equipo visitante: "))

    # 2. Crear un nuevo DataFrame con los datos del usuario
    nuevo_dataframe = datos_usuario(df, equipo_local, equipo_visitante)

    # 3. Escalar las características del nuevo DataFrame
    X_prediccion = scaler.transform(nuevo_dataframe)

    # Obtener la predicción y la probabilidad asociada
    predicciones =  model.predict(X_prediccion)

    for i, pred in enumerate(predicciones):
        if pred == 1:
            print(f"Predicción para el partido {equipo_local} vs. {equipo_visitante}:\n Ambos equipos marcan goles")
        else:
            print(f"Predicción para el partido {equipo_local} vs. {equipo_visitante}:\n Al menos un equipo no marca gol")


if __name__ == "__main__":
    main()
# Out:
# Seleccione el equipo local:
# [ 27  38  76  36  49  94   8   1   2  69   3  31  21  46  43   9  95  61
#   44 186   7  85  50  15  12   6  99  11  17 190 151  29  25  92  28  32
#    4 303  37  88   5  93  98 103 323 368  10  47  51 350 355 154  55  87
#  153  19  18  60 142  57 305  80  89 294 140 322  39 301 252  24  48 122
#  298  53 189 378 310 346 110 484 374 316 308 123 339  33 299 336  14 235
#   16 513  90 160 125 469 482  62 296 105  40 297 188  34 306  59 126 366
#   22  68 300  20  67 464 184 108 485 321 352 379  97 295  41 470 328 191
#  307]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicción para el partido 14 vs. 28:
#  Al menos un equipo no marca gol
