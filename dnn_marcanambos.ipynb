# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

class LoadData:
    def __init__(self, file_path):
        self.file_path = file_path

    def load_data(self):
        data = pd.read_csv(self.file_path)
        return data

    def prepare_data(self, data):
        # Convertir la columna "Ronda" en variables dummy
        data = pd.get_dummies(data, columns=['Ronda'], drop_first=True)

        # Suponiendo que tu DataFrame se llama 'dataframe'
        data['MarcanAmbos'] = (data['GolesLocal'] > 0) & (data['GolesVisitante'] > 0)
        data['MarcanAmbos'] = data['MarcanAmbos'].astype(int)

        # Eliminar columnas irrelevantes
        data = data.drop(['idPartido', 'Temporada', 'Evento', 'GolesLocal', 'GolesVisitante'], axis=1)

        # Separar características y etiquetas
        X = data.drop(['VictoriaLocal', 'Empate', 'VictoriaVisitante', 'MarcanAmbos'], axis=1)
        y = data['MarcanAmbos']

        # Escalar características
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        # Dividir los datos en conjuntos de entrenamiento y prueba
        X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
        
        # Convertir los datos a tensores
        X_train = tf.convert_to_tensor(X_train, dtype=tf.float32)
        X_test = tf.convert_to_tensor(X_test, dtype=tf.float32)
        y_train = tf.convert_to_tensor(y_train.values, dtype=tf.float32)
        y_test = tf.convert_to_tensor(y_test.values, dtype=tf.float32)
        
        return X_train, X_test, y_train, y_test, scaler, X, y
    
# Cargar los datos
data_loader = LoadData('dataframe/champions.csv')
data = data_loader.load_data()
X_train, X_test, y_train, y_test, scaler, X, y = data_loader.prepare_data(data)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, Reshape
from tensorflow.keras.optimizers import Adam

class Model:
    def __init__(self, configurations):
        self.configurations = configurations
        self.best_model = None
        self.best_config = None
        self.best_accuracy = 0

    def train_model(self, X_train, y_train):
        for config in self.configurations:
            model = Sequential([
                Reshape((X_train.shape[1], 1), input_shape=(X_train.shape[1],)),
                Conv1D(config['filters'], config['kernel_size'], activation='relu'),
                MaxPooling1D(),
                Flatten(),
                Dense(config['units'], activation='relu'),
                Dropout(config['dropout']),
                Dense(1, activation='sigmoid')
            ])

            optimizer = Adam(learning_rate=config['learning_rate'])
            model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

            history = model.fit(X_train, y_train, epochs=config['epochs'], batch_size=config['batch_size'], validation_split=0.1)
            self.history = history.history  # Almacenar el historial de entrenamiento
            
            
            _, accuracy = model.evaluate(X_test, y_test)
            
            if accuracy > self.best_accuracy:
                self.best_accuracy = accuracy
                self.best_model = model
                self.best_config = config

        return self.history
    
    def get_best_model(self):
        return self.best_model
    
    def get_best_config(self):
        return self.best_config
    

# Definir diferentes configuraciones de red y hiperparámetros
configurations = [
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2}, 
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2},
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2},
    {'units': 128, 'filters': 64, 'kernel_size': 3, 'learning_rate': 0.01, 'batch_size': 64, 'epochs': 15, 'dropout': 0.1},
    {'units': 256, 'filters': 128, 'kernel_size': 5, 'learning_rate': 0.0001, 'batch_size': 16, 'epochs': 10, 'dropout': 0.3},
    {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2}
]



model_trainer = Model(configurations)
model_trainer.train_model(X_train, y_train)

model = model_trainer.get_best_model()
best_config = model_trainer.get_best_config()
print("Mejor configuración:", best_config)
# Out:
# Epoch 1/15
# /Users/carlotasanchezgonzalez/anaconda3/lib/python3.11/site-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5262 - loss: 0.7292 - val_accuracy: 0.4629 - val_loss: 0.7039
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5132 - loss: 0.6933 - val_accuracy: 0.5657 - val_loss: 0.6830
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5370 - loss: 0.6893 - val_accuracy: 0.5257 - val_loss: 0.6863
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5514 - loss: 0.6822 - val_accuracy: 0.4914 - val_loss: 0.7002
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5490 - loss: 0.6864 - val_accuracy: 0.5200 - val_loss: 0.6925
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5530 - loss: 0.6820 - val_accuracy: 0.6057 - val_loss: 0.6679
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5721 - loss: 0.6791 - val_accuracy: 0.5657 - val_loss: 0.6706
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5473 - loss: 0.6779 - val_accuracy: 0.5086 - val_loss: 0.6988
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5874 - loss: 0.6704 - val_accuracy: 0.5257 - val_loss: 0.6809
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6008 - loss: 0.6634 - val_accuracy: 0.4857 - val_loss: 0.6988
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6002 - loss: 0.6662 - val_accuracy: 0.4629 - val_loss: 0.6990
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6147 - loss: 0.6592 - val_accuracy: 0.5429 - val_loss: 0.6952
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5941 - loss: 0.6603 - val_accuracy: 0.5143 - val_loss: 0.7023
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6195 - loss: 0.6539 - val_accuracy: 0.5029 - val_loss: 0.7449
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6361 - loss: 0.6465 - val_accuracy: 0.5029 - val_loss: 0.7155
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.5404 - loss: 0.7081
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4684 - loss: 0.7016 - val_accuracy: 0.5029 - val_loss: 0.7020
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5527 - loss: 0.6885 - val_accuracy: 0.5029 - val_loss: 0.6992
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5418 - loss: 0.6850 - val_accuracy: 0.5029 - val_loss: 0.6828
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5507 - loss: 0.6819 - val_accuracy: 0.5543 - val_loss: 0.6732
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5676 - loss: 0.6755 - val_accuracy: 0.5257 - val_loss: 0.6921
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5888 - loss: 0.6784 - val_accuracy: 0.5200 - val_loss: 0.6846
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5633 - loss: 0.6794 - val_accuracy: 0.5086 - val_loss: 0.7015
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5653 - loss: 0.6757 - val_accuracy: 0.5029 - val_loss: 0.6955
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6003 - loss: 0.6669 - val_accuracy: 0.5200 - val_loss: 0.7060
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6038 - loss: 0.6695 - val_accuracy: 0.5143 - val_loss: 0.6773
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.5323 - loss: 0.6902
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5119 - loss: 0.7047 - val_accuracy: 0.5029 - val_loss: 0.6923
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5329 - loss: 0.6876 - val_accuracy: 0.5143 - val_loss: 0.6825
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5567 - loss: 0.6909 - val_accuracy: 0.5543 - val_loss: 0.6849
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5640 - loss: 0.6811 - val_accuracy: 0.5257 - val_loss: 0.6828
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5520 - loss: 0.6845 - val_accuracy: 0.5543 - val_loss: 0.6939
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5928 - loss: 0.6684 - val_accuracy: 0.5257 - val_loss: 0.6872
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5803 - loss: 0.6708 - val_accuracy: 0.5257 - val_loss: 0.6980
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5958 - loss: 0.6727 - val_accuracy: 0.5371 - val_loss: 0.6864
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6072 - loss: 0.6593 - val_accuracy: 0.5086 - val_loss: 0.7114
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5740 - loss: 0.6689 - val_accuracy: 0.5314 - val_loss: 0.6969
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - accuracy: 0.5035 - loss: 0.6958
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4940 - loss: 0.9443 - val_accuracy: 0.5371 - val_loss: 0.6925
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5152 - loss: 0.6928 - val_accuracy: 0.5486 - val_loss: 0.6926
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5286 - loss: 0.6927 - val_accuracy: 0.5486 - val_loss: 0.6928
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5162 - loss: 0.6925 - val_accuracy: 0.5314 - val_loss: 0.6963
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5314 - loss: 0.6903 - val_accuracy: 0.5429 - val_loss: 0.6939
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5294 - loss: 0.6908 - val_accuracy: 0.5314 - val_loss: 0.6947
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5467 - loss: 0.6882 - val_accuracy: 0.5086 - val_loss: 0.6968
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5393 - loss: 0.6868 - val_accuracy: 0.5086 - val_loss: 0.6955
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5357 - loss: 0.6881 - val_accuracy: 0.5143 - val_loss: 0.6882
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5612 - loss: 0.6814 - val_accuracy: 0.5143 - val_loss: 0.6963
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5892 - loss: 0.6804 - val_accuracy: 0.5029 - val_loss: 0.6857
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5709 - loss: 0.6806 - val_accuracy: 0.4971 - val_loss: 0.6892
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5683 - loss: 0.6806 - val_accuracy: 0.5200 - val_loss: 0.6873
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5561 - loss: 0.6756 - val_accuracy: 0.4971 - val_loss: 0.6919
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5723 - loss: 0.6788 - val_accuracy: 0.5314 - val_loss: 0.6881
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.5346 - loss: 0.6956
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5052 - loss: 0.6941 - val_accuracy: 0.5029 - val_loss: 0.7007
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5214 - loss: 0.6920 - val_accuracy: 0.5086 - val_loss: 0.6962
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5447 - loss: 0.6897 - val_accuracy: 0.5314 - val_loss: 0.7029
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5470 - loss: 0.6862 - val_accuracy: 0.5257 - val_loss: 0.6988
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5795 - loss: 0.6794 - val_accuracy: 0.4800 - val_loss: 0.6935
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5810 - loss: 0.6720 - val_accuracy: 0.5143 - val_loss: 0.6833
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5972 - loss: 0.6742 - val_accuracy: 0.5486 - val_loss: 0.6713
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5717 - loss: 0.6696 - val_accuracy: 0.5486 - val_loss: 0.6731
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5861 - loss: 0.6685 - val_accuracy: 0.5657 - val_loss: 0.6753
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5853 - loss: 0.6676 - val_accuracy: 0.5143 - val_loss: 0.6775
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.5278 - loss: 0.6916
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5132 - loss: 0.7016 - val_accuracy: 0.5886 - val_loss: 0.6750
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5373 - loss: 0.6914 - val_accuracy: 0.5371 - val_loss: 0.6787
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 0.5738 - loss: 0.6843 - val_accuracy: 0.4800 - val_loss: 0.7035
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5491 - loss: 0.6818 - val_accuracy: 0.5029 - val_loss: 0.6986
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5775 - loss: 0.6791 - val_accuracy: 0.5314 - val_loss: 0.6827
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5611 - loss: 0.6843 - val_accuracy: 0.4971 - val_loss: 0.6944
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5832 - loss: 0.6799 - val_accuracy: 0.5543 - val_loss: 0.6874
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6119 - loss: 0.6693 - val_accuracy: 0.4971 - val_loss: 0.7154
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6103 - loss: 0.6668 - val_accuracy: 0.5086 - val_loss: 0.6890
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5816 - loss: 0.6718 - val_accuracy: 0.4857 - val_loss: 0.7257
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.5382 - loss: 0.6968
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4975 - loss: 0.8084 - val_accuracy: 0.5143 - val_loss: 0.6900
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5467 - loss: 0.6910 - val_accuracy: 0.4914 - val_loss: 0.6911
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5356 - loss: 0.6889 - val_accuracy: 0.4629 - val_loss: 0.6922
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5460 - loss: 0.6845 - val_accuracy: 0.5943 - val_loss: 0.6679
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5625 - loss: 0.6827 - val_accuracy: 0.4800 - val_loss: 0.7110
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5527 - loss: 0.6802 - val_accuracy: 0.4914 - val_loss: 0.6999
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5597 - loss: 0.6847 - val_accuracy: 0.4857 - val_loss: 0.7070
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5725 - loss: 0.6824 - val_accuracy: 0.5143 - val_loss: 0.7119
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5761 - loss: 0.6788 - val_accuracy: 0.4629 - val_loss: 0.7289
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5692 - loss: 0.6780 - val_accuracy: 0.5029 - val_loss: 0.6870
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5970 - loss: 0.6698 - val_accuracy: 0.5371 - val_loss: 0.6994
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6115 - loss: 0.6612 - val_accuracy: 0.5429 - val_loss: 0.6835
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5923 - loss: 0.6646 - val_accuracy: 0.5371 - val_loss: 0.6815
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6029 - loss: 0.6614 - val_accuracy: 0.4971 - val_loss: 0.7179
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6175 - loss: 0.6477 - val_accuracy: 0.4857 - val_loss: 0.7158
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - accuracy: 0.5260 - loss: 0.7138
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4984 - loss: 0.6989 - val_accuracy: 0.5657 - val_loss: 0.6758
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5487 - loss: 0.6881 - val_accuracy: 0.5371 - val_loss: 0.6856
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5492 - loss: 0.6792 - val_accuracy: 0.5314 - val_loss: 0.6971
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5603 - loss: 0.6784 - val_accuracy: 0.5029 - val_loss: 0.6858
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5770 - loss: 0.6739 - val_accuracy: 0.5257 - val_loss: 0.6814
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5600 - loss: 0.6765 - val_accuracy: 0.5200 - val_loss: 0.6951
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5876 - loss: 0.6714 - val_accuracy: 0.5371 - val_loss: 0.6782
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5869 - loss: 0.6721 - val_accuracy: 0.5600 - val_loss: 0.6820
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6021 - loss: 0.6735 - val_accuracy: 0.5257 - val_loss: 0.6711
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5822 - loss: 0.6698 - val_accuracy: 0.5086 - val_loss: 0.6974
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.5283 - loss: 0.6926
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4837 - loss: 0.6970 - val_accuracy: 0.5371 - val_loss: 0.6848
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5417 - loss: 0.6856 - val_accuracy: 0.4800 - val_loss: 0.6930
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5687 - loss: 0.6834 - val_accuracy: 0.4971 - val_loss: 0.6887
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5494 - loss: 0.6840 - val_accuracy: 0.4914 - val_loss: 0.6866
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5578 - loss: 0.6828 - val_accuracy: 0.5257 - val_loss: 0.6948
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5773 - loss: 0.6779 - val_accuracy: 0.5257 - val_loss: 0.6930
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5584 - loss: 0.6799 - val_accuracy: 0.5029 - val_loss: 0.6872
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5989 - loss: 0.6725 - val_accuracy: 0.5371 - val_loss: 0.6836
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5691 - loss: 0.6793 - val_accuracy: 0.5257 - val_loss: 0.6923
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5931 - loss: 0.6726 - val_accuracy: 0.5029 - val_loss: 0.6864
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.5268 - loss: 0.6905
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4846 - loss: 0.7120 - val_accuracy: 0.6057 - val_loss: 0.6822
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5149 - loss: 0.6935 - val_accuracy: 0.4686 - val_loss: 0.7098
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5353 - loss: 0.6895 - val_accuracy: 0.5086 - val_loss: 0.6912
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5436 - loss: 0.6905 - val_accuracy: 0.5200 - val_loss: 0.6892
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5685 - loss: 0.6767 - val_accuracy: 0.5200 - val_loss: 0.6891
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5684 - loss: 0.6795 - val_accuracy: 0.5086 - val_loss: 0.6836
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5823 - loss: 0.6811 - val_accuracy: 0.5029 - val_loss: 0.6967
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5821 - loss: 0.6722 - val_accuracy: 0.5371 - val_loss: 0.6815
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5903 - loss: 0.6716 - val_accuracy: 0.5829 - val_loss: 0.6683
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5681 - loss: 0.6771 - val_accuracy: 0.5029 - val_loss: 0.6895
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - accuracy: 0.5014 - loss: 0.6998
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4907 - loss: 0.9148 - val_accuracy: 0.5200 - val_loss: 0.6915
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5316 - loss: 0.6917 - val_accuracy: 0.5486 - val_loss: 0.6900
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5541 - loss: 0.6906 - val_accuracy: 0.4857 - val_loss: 0.6908
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5363 - loss: 0.6908 - val_accuracy: 0.4914 - val_loss: 0.6876
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5568 - loss: 0.6849 - val_accuracy: 0.4686 - val_loss: 0.6927
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5432 - loss: 0.6868 - val_accuracy: 0.4914 - val_loss: 0.6875
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5634 - loss: 0.6818 - val_accuracy: 0.4800 - val_loss: 0.6944
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5746 - loss: 0.6779 - val_accuracy: 0.5657 - val_loss: 0.6736
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5444 - loss: 0.6875 - val_accuracy: 0.5029 - val_loss: 0.6874
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5661 - loss: 0.6790 - val_accuracy: 0.5714 - val_loss: 0.6689
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5545 - loss: 0.6817 - val_accuracy: 0.5371 - val_loss: 0.6833
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5652 - loss: 0.6802 - val_accuracy: 0.4971 - val_loss: 0.7039
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5534 - loss: 0.6772 - val_accuracy: 0.5143 - val_loss: 0.7001
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5697 - loss: 0.6743 - val_accuracy: 0.4857 - val_loss: 0.7186
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5881 - loss: 0.6708 - val_accuracy: 0.4914 - val_loss: 0.7051
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.4864 - loss: 0.7099
# Epoch 1/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4843 - loss: 0.6989 - val_accuracy: 0.4971 - val_loss: 0.6894
# Epoch 2/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5681 - loss: 0.6852 - val_accuracy: 0.5600 - val_loss: 0.6803
# Epoch 3/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5298 - loss: 0.6916 - val_accuracy: 0.4971 - val_loss: 0.6919
# Epoch 4/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5629 - loss: 0.6811 - val_accuracy: 0.5200 - val_loss: 0.6780
# Epoch 5/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5525 - loss: 0.6753 - val_accuracy: 0.5029 - val_loss: 0.7011
# Epoch 6/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5632 - loss: 0.6768 - val_accuracy: 0.4857 - val_loss: 0.7011
# Epoch 7/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5865 - loss: 0.6809 - val_accuracy: 0.5257 - val_loss: 0.7016
# Epoch 8/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5730 - loss: 0.6765 - val_accuracy: 0.5314 - val_loss: 0.6800
# Epoch 9/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5771 - loss: 0.6709 - val_accuracy: 0.5086 - val_loss: 0.6845
# Epoch 10/10
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6230 - loss: 0.6635 - val_accuracy: 0.5257 - val_loss: 0.6790
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.5076 - loss: 0.6960
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5072 - loss: 0.7033 - val_accuracy: 0.4686 - val_loss: 0.7003
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5342 - loss: 0.6870 - val_accuracy: 0.4514 - val_loss: 0.7091
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5739 - loss: 0.6849 - val_accuracy: 0.5029 - val_loss: 0.7083
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5453 - loss: 0.6901 - val_accuracy: 0.5486 - val_loss: 0.6835
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6101 - loss: 0.6753 - val_accuracy: 0.4400 - val_loss: 0.7313
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5580 - loss: 0.6875 - val_accuracy: 0.5029 - val_loss: 0.6969
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5832 - loss: 0.6724 - val_accuracy: 0.5429 - val_loss: 0.6950
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.6151 - loss: 0.6584 - val_accuracy: 0.5543 - val_loss: 0.6849
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5894 - loss: 0.6681 - val_accuracy: 0.5314 - val_loss: 0.6976
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6142 - loss: 0.6613 - val_accuracy: 0.5429 - val_loss: 0.6986
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - accuracy: 0.5509 - loss: 0.6910
# Mejor configuración: {'units': 64, 'filters': 32, 'kernel_size': 3, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 10, 'dropout': 0.2}

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix

class ModelEvaluation:
    def __init__(self, model):
        self.model = model
    
    def evaluate_model(self, X_test, y_test):
        # Evaluar el modelo
        loss, accuracy = self.model.evaluate(X_test, y_test)
        print("Loss:", loss)
        print("Accuracy:", accuracy)

        # Generar predicciones
        class_probabilities = self.model.predict(X_test)
        predictions = np.round(class_probabilities).flatten()
        true_labels = y_test.numpy().flatten()

        # Calcular y mostrar la matriz de confusión
        conf_matrix = confusion_matrix(true_labels, predictions)
        print("Confusion Matrix:")
        print(conf_matrix)

        self.plot_matriz_confusion(conf_matrix)

    def plot_matriz_confusion(self, conf_matrix):
        # Visualizar la matriz de confusión
        plt.imshow(conf_matrix, interpolation="nearest", cmap=plt.cm.Blues)
        plt.colorbar()
        tick_marks = np.arange(2)
        plt.xticks(tick_marks, ['No Marcan Ambos', 'Marcan Ambos'], rotation=45)
        plt.yticks(tick_marks, ['No Marcan Ambos', 'Marcan Ambos'])
        plt.xlabel("Predicted Class")
        plt.ylabel("True Class")
        plt.title("Confusion Matrix")
        plt.show()

    @staticmethod
    def plot_learning_curve_tf(history):
        train_loss = history['loss']
        val_loss = history['val_loss']
        train_accuracy = history['accuracy']
        val_accuracy = history['val_accuracy']
        
        epochs = range(1, len(train_loss) + 1)
        
        plt.figure(figsize=(20, 6))
        
        plt.subplot(1, 2, 1)
        plt.plot(epochs, train_loss, 'r', label='Training loss')
        plt.plot(epochs, val_loss, 'b', label='Validation loss')
        plt.title('Training and validation loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        
        plt.subplot(1, 2, 2)
        plt.plot(epochs, train_accuracy, 'r', label='Training accuracy')
        plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        
        plt.show()

# Asumiendo que ya tienes el modelo entrenado (model) y los datos de prueba (X_test, y_test)
model_evaluator = ModelEvaluation(model)
model_evaluator.evaluate_model(X_test, y_test)

ModelEvaluation.plot_learning_curve_tf(model_trainer.history)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.5509 - loss: 0.6910
# Loss: 0.6945850253105164
# Accuracy: 0.5420560836791992
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Confusion Matrix:
# [[172 215]
#  [128 234]]

# %%
# Guardar el modelo
tf.keras.models.save_model(model, 'modelos/dnn_ambos_marcan.keras')
model = tf.keras.models.load_model("modelos/dnn_ambos_marcan.keras")

# %%
import pandas as pd

# Cargar los datos
df = pd.read_csv("dataframe/champions_23_24.csv")
df = pd.concat([df, data], ignore_index=True)

# Suponiendo que tu DataFrame se llama df
df = df.sort_values(by=['Temporada', 'Ronda'], ascending=[True, True])
df = pd.get_dummies(df, columns=['Ronda'], drop_first=True)

df
# Out:
#       idPartido   Temporada  Local  Visitante  \
# 2617       2618  2003-01-01     27         12
# 2493       2494  2003-01-01     38        190
# 2494       2495  2003-01-01     76         11
# 2495       2496  2003-01-01     36         12
# 2496       2497  2003-01-01     49        151
# ...         ...         ...    ...        ...
# 111         112  2023-01-01     24          7
# 120         121  2023-01-01      3          1
# 121         122  2023-01-01     14         28
# 122         123  2023-01-01     28         14
# 123         124  2023-01-01      1          3
#
#                                Evento  GolesLocal  GolesVisitante  \
# 2617  Arena AufSchalke (Neutral Site)           0               3
# 2493               Jan Breydelstadion           1               1
# 2494                    Stadion Letná           0               1
# 2495              Stadion FK Partizan           1               1
# 2496                    Ibrox Stadium           2               1
# ...                               ...         ...             ...
# 111             Stadium Metropolitano           2               1
# 120                     Allianz Arena           0               0
# 121                 Signal Iduna Park           0               0
# 122                  Parc des Princes           0               0
# 123         Estadio Santiago Bernabéu           0               0
#
#       VictoriaLocal  Empate  VictoriaVisitante  ...  %_2_P_Temporada_L  \
# 2617              0       0                  1  ...              16.67
# 2493              0       1                  0  ...              25.00
# 2494              0       0                  1  ...              16.67
# 2495              0       1                  0  ...              16.67
# 2496              1       0                  0  ...              25.00
# ...             ...     ...                ...  ...                ...
# 111               0       0                  1  ...               0.00
# 120               0       1                  0  ...               0.00
# 121               0       1                  0  ...              16.67
# 122               0       1                  0  ...               0.00
# 123               0       1                  0  ...               0.00
#
#       2_Media_G  2_Media_G_Local  2_Media_Goles_PP  2_ValorJugadores  \
# 2617       0.50             0.67              1.42        765.322916
# 2493       0.29             0.25              1.14        491.567176
# 2494       0.45             0.17              1.36        694.733672
# 2495       0.58             0.67              1.58        765.322916
# 2496       0.57             0.75              1.14        512.353693
# ...         ...              ...               ...               ...
# 111        0.57             0.75              1.29        540.296221
# 120        0.73             0.50              2.00        685.750766
# 121        0.45             0.50              1.73        698.621042
# 122        0.45             0.50              1.36        642.492339
# 123        0.64             0.67              1.64        675.229826
#
#       2_MediaJugadores  Ronda_Group stage  Ronda_Quarter-finals  \
# 2617         34.787405              False                 False
# 2493         23.407961               True                 False
# 2494         33.082556               True                 False
# 2495         34.787405               True                 False
# 2496         24.397795               True                 False
# ...                ...                ...                   ...
# 111          24.558919              False                 False
# 120          31.170489              False                 False
# 121          33.267669              False                 False
# 122          27.934450              False                 False
# 123          29.357819              False                 False
#
#       Ronda_Round of 16  Ronda_Semi-finals
# 2617              False              False
# 2493              False              False
# 2494              False              False
# 2495              False              False
# 2496              False              False
# ...                 ...                ...
# 111                True              False
# 120               False               True
# 121               False               True
# 122               False               True
# 123               False               True
#
# [2618 rows x 37 columns]

# %%
def datos_usuario(df, equipo_local, equipo_visitante):
    # Filtrar el DataFrame para obtener la última fila donde el equipo local y visitante coincidan con los ingresados por el usuario
    filtro_ultimo_partido = ((df['Local'] == equipo_local) & (df['Visitante'] == equipo_visitante)) | ((df['Local'] == equipo_visitante) & (df['Visitante'] == equipo_local))

    # Obtener el último partido entre los equipos ingresados por el usuario
    ultimo_partido_entre_equipos = df[filtro_ultimo_partido].iloc[-1]

    # Obtener los valores para las columnas %_Victorias_Local, %_Empate, %_Victoria_Visitante
    valores_prediccion = ultimo_partido_entre_equipos[['%_Victorias_Local', '%_Empate', '%_Victoria_Visitante', 'Ronda_Group stage', 'Ronda_Quarter-finals',	'Ronda_Round of 16', 'Ronda_Semi-finals']]

    if ultimo_partido_entre_equipos['Local'] == equipo_local and ultimo_partido_entre_equipos['Visitante'] == equipo_visitante:
        porcentajes_de_los_dos = ultimo_partido_entre_equipos[['%_Equipo1_Ganado', '%_Equipo2_Ganado']]

    elif ultimo_partido_entre_equipos['Local'] == equipo_visitante and ultimo_partido_entre_equipos['Visitante'] == equipo_local:
        porcentajes_de_los_dos = ultimo_partido_entre_equipos[['%_Equipo1_Ganado', '%_Equipo2_Ganado']]
        porcentajes_de_los_dos = porcentajes_de_los_dos.rename({'%_Equipo1_Ganado': '%_Equipo2_Ganado', '%_Equipo2_Ganado': '%_Equipo1_Ganado'})


    # 3. Filtrar el DataFrame para obtener las estadísticas del equipo local
    filtro_local = (df['Local'] == equipo_local) | (df['Visitante'] == equipo_local)
    ultima_aparicion_local = df[filtro_local].iloc[-1]
    if ultima_aparicion_local['Local'] == equipo_local:
        estadisticas_equipo_local = ultima_aparicion_local[['%_1_G_Temporada', '%_1_G_Temporada_L', '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G', '1_Media_G_Local', '1_Media_Goles_PP', '1_ValorJugadores', '1_MediaJugadores']]
    elif ultima_aparicion_local['Visitante'] == equipo_local:
        estadisticas_equipo_local = ultima_aparicion_local[['%_2_G_Temporada', '%_2_G_Temporada_L', '%_2_E_Temporada_L', '%_2_P_Temporada_L', '2_Media_G', '2_Media_G_Local', '2_Media_Goles_PP', '2_ValorJugadores', '2_MediaJugadores']]
        #Cambiar el numero del nombre de las columnas porque si es el local del usuario pasara a ser las columnas con 1 en vez de 2
        estadisticas_equipo_local.index = ['%_1_G_Temporada', '%_1_G_Temporada_L', '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G', '1_Media_G_Local', '1_Media_Goles_PP', '1_ValorJugadores', '1_MediaJugadores']

    # 4. Filtrar el DataFrame para obtener las estadísticas del equipo visitante
    filtro_visitante = (df['Local'] == equipo_visitante) | (df['Visitante'] == equipo_visitante)
    ultima_aparicion_visitante = df[filtro_visitante].iloc[-1]
    if ultima_aparicion_visitante['Local'] == equipo_visitante:
        estadisticas_equipo_visitante = ultima_aparicion_visitante[['%_1_G_Temporada', '%_1_G_Temporada_L', '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G', '1_Media_G_Local', '1_Media_Goles_PP', '1_ValorJugadores', '1_MediaJugadores']]
        estadisticas_equipo_visitante = estadisticas_equipo_visitante.rename({'%_1_G_Temporada': '%_2_G_Temporada', '%_1_G_Temporada_L': '%_2_G_Temporada_L', '%_1_E_Temporada_L': '%_2_E_Temporada_L', '%_1_P_Temporada_L': '%_2_P_Temporada_L', '1_Media_G': '2_Media_G', '1_Media_G_Local': '2_Media_G_Local', '1_Media_Goles_PP': '2_Media_Goles_PP', '1_ValorJugadores': '2_ValorJugadores', '1_MediaJugadores': '2_MediaJugadores'})
    elif ultima_aparicion_visitante['Visitante'] == equipo_visitante:
        estadisticas_equipo_visitante = ultima_aparicion_visitante[['%_2_G_Temporada', '%_2_G_Temporada_L', '%_2_E_Temporada_L', '%_2_P_Temporada_L', '2_Media_G', '2_Media_G_Local', '2_Media_Goles_PP', '2_ValorJugadores', '2_MediaJugadores']]


    # Combinar las estadísticas de ambos equipos para predecir el resultado del partido
    datos_partido = pd.concat([estadisticas_equipo_local, estadisticas_equipo_visitante, valores_prediccion, porcentajes_de_los_dos])

    # Crear un nuevo DataFrame vacío con las columnas especificadas en el orden deseado
    nuevo_dataframe = pd.DataFrame(columns=['Local', 'Visitante', '%_Victorias_Local', '%_Empate', '%_Victoria_Visitante',
                                            '%_Equipo1_Ganado', '%_Equipo2_Ganado', '%_1_G_Temporada', '%_1_G_Temporada_L',
                                            '%_1_E_Temporada_L', '%_1_P_Temporada_L', '1_Media_G', '1_Media_G_Local', '1_Media_Goles_PP',
                                            '1_ValorJugadores', '1_MediaJugadores', '%_2_G_Temporada', '%_2_G_Temporada_L',
                                            '%_2_E_Temporada_L', '%_2_P_Temporada_L', '2_Media_G', '2_Media_G_Local', '2_Media_Goles_PP',
                                            '2_ValorJugadores', '2_MediaJugadores', 'Ronda_Group stage', 'Ronda_Quarter-finals', 'Ronda_Round of 16', 'Ronda_Semi-finals'])

    # Agregar una fila con los valores proporcionados al nuevo DataFrame
    nuevo_dataframe.loc[0] = [equipo_local, equipo_visitante, datos_partido['%_Victorias_Local'], datos_partido['%_Empate'],
                            datos_partido['%_Victoria_Visitante'], datos_partido['%_Equipo1_Ganado'], datos_partido['%_Equipo2_Ganado'],
                            datos_partido['%_1_G_Temporada'], datos_partido['%_1_G_Temporada_L'], datos_partido['%_1_E_Temporada_L'],
                            datos_partido['%_1_P_Temporada_L'], datos_partido['1_Media_G'], datos_partido['1_Media_G_Local'],
                            datos_partido['1_Media_Goles_PP'], datos_partido['1_ValorJugadores'], datos_partido['1_MediaJugadores'],
                            datos_partido['%_2_G_Temporada'], datos_partido['%_2_G_Temporada_L'], datos_partido['%_2_E_Temporada_L'],
                            datos_partido['%_2_P_Temporada_L'], datos_partido['2_Media_G'], datos_partido['2_Media_G_Local'],
                            datos_partido['2_Media_Goles_PP'], datos_partido['2_ValorJugadores'], datos_partido['2_MediaJugadores'],
                            datos_partido['Ronda_Group stage'], datos_partido['Ronda_Quarter-finals'], datos_partido['Ronda_Round of 16'], datos_partido['Ronda_Semi-finals']]


    return nuevo_dataframe


datos_usuario(df, 14, 28)
# Out:
#    Local  Visitante  %_Victorias_Local  %_Empate  %_Victoria_Visitante  \
# 0     14         28               60.0      40.0                   0.0
#
#    %_Equipo1_Ganado  %_Equipo2_Ganado  %_1_G_Temporada  %_1_G_Temporada_L  \
# 0              20.0              40.0            45.45               50.0
#
#    %_1_E_Temporada_L  ...  %_2_P_Temporada_L  2_Media_G  2_Media_G_Local  \
# 0               50.0  ...               20.0       0.45              0.6
#
#    2_Media_Goles_PP  2_ValorJugadores  2_MediaJugadores  Ronda_Group stage  \
# 0              1.73        698.621042         33.267669              False
#
#    Ronda_Quarter-finals  Ronda_Round of 16  Ronda_Semi-finals
# 0                 False              False               True
#
# [1 rows x 29 columns]

# %%
def main():
    # 1. Pedir al usuario que ingrese el equipo local
    print("Seleccione el equipo local:")
    equipos_disponibles = df['Local'].unique()
    print(equipos_disponibles)

    equipo_local = input("Ingrese el nombre del equipo local: ")
    equipo_visitante = input("Ingrese el nombre del equipo visitante: ")

    # 2. Crear un nuevo DataFrame con los datos del usuario
    nuevo_dataframe = datos_usuario(df, equipo_local, equipo_visitante)

    # 3. Escalar las características del nuevo DataFrame
    X_prediccion = scaler.transform(nuevo_dataframe)

    # 4. Predecir si ambos equipos marcarán goles con el modelo
    class_probabilities_prediccion = model.predict(X_prediccion)
    if class_probabilities_prediccion[0] >= 0.5:
        print(f"Predicción: Ambos equipos marcarán goles en el partido entre {equipo_local} y {equipo_visitante}.")
    else:
        print(f"Predicción: Al menos un equipo no marcará gol en el partido entre {equipo_local} y {equipo_visitante}.")


if __name__ == "__main__":
    main()
# Out:
# Seleccione el equipo local:
# [ 27  38  76  36  49  94   8   1   2  69   3  31  21  46  43   9  95  61
#   44 186   7  85  50  15  12   6  99  11  17 190 151  29  25  92  28  32
#    4 303  37  88   5  93  98 103 323 368  10  47  51 350 355 154  55  87
#  153  19  18  60 142  57 305  80  89 294 140 322  39 301 252  24  48 122
#  298  53 189 378 310 346 110 484 374 316 308 123 339  33 299 336  14 235
#   16 513  90 160 125 469 482  62 296 105  40 297 188  34 306  59 126 366
#   22  68 300  20  67 464 184 108 485 321 352 379  97 295  41 470 328 191
#  307]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[57], line 26
#      22         print(f"Predicción: Al menos un equipo no marcará gol en el partido entre {equipo_local} y {equipo_visitante}.")
#      25 if __name__ == "__main__":
# ---> 26     main()
#
# Cell In[57], line 11, in main()
#       8 equipo_visitante = input("Ingrese el nombre del equipo visitante: ")
#      10 # 2. Crear un nuevo DataFrame con los datos del usuario
# ---> 11 nuevo_dataframe = datos_usuario(df, equipo_local, equipo_visitante)
#      12 print(nuevo_dataframe)
#      14 # 3. Escalar las características del nuevo DataFrame
#
# Cell In[56], line 6, in datos_usuario(df, equipo_local, equipo_visitante)
#       3 filtro_ultimo_partido = ((df['Local'] == equipo_local) & (df['Visitante'] == equipo_visitante)) | ((df['Local'] == equipo_visitante) & (df['Visitante'] == equipo_local))
#       5 # Obtener el último partido entre los equipos ingresados por el usuario
# ----> 6 ultimo_partido_entre_equipos = df[filtro_ultimo_partido].iloc[-1]
#       8 # Obtener los valores para las columnas %_Victorias_Local, %_Empate, %_Victoria_Visitante
#       9 valores_prediccion = ultimo_partido_entre_equipos[['%_Victorias_Local', '%_Empate', '%_Victoria_Visitante', 'Ronda_Group stage', 'Ronda_Quarter-finals',	'Ronda_Round of 16', 'Ronda_Semi-finals']]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1656, in _iLocIndexer._getitem_axis(self, key, axis)
#    1653     raise TypeError("Cannot index by location index with a non-integer key")
#    1655 # validate the location
# -> 1656 self._validate_integer(key, axis)
#    1658 return self.obj._ixs(key, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1589, in _iLocIndexer._validate_integer(self, key, axis)
#    1587 len_axis = len(self.obj._get_axis(axis))
#    1588 if key >= len_axis or key < -len_axis:
# -> 1589     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
